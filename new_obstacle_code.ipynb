# %% [markdown]
# Importing libraries

# %%
import numpy as np
import sympy as sp
import os
from queue import PriorityQueue
import matplotlib.pyplot as mp

# %% [markdown]
# Note: workspace is a rectangle of width b = 400 mm and height h = 250 mm

# %% [markdown]
# Variables:
# C2C
# C2G
# closed_list
# open _list
# initial_node
# goal_node
# obstacle_space usign matrix and geometric equations
# action_set --> N(1),S(1), E(1), W(1), NE(1.5), NW, SE, SW

# %% [markdown]
# Creating the workspace with all default values at once

# %%
#node size ratio (unit/node)
def map():
    global x_size, y_size, map_def, Rat
    Rat = 0.5
    x_size = int(400/Rat) #x and y  as per gloabl coordinate system and not matrix
    y_size = int(250/Rat)
    map_def = np.zeros((y_size,x_size,12))
    map_def[:,:,:] = -2

# %%
map()

# %% [markdown]
# Common obstacle code

# %% [markdown]
# Circle

# %%
#x is column and y is row for the matrix
def circle_obs():
    global x_c, y_c, x_nc, y_nc, map_obs1, allp_map, Rat
    allp_map = []
    x_c = []
    y_c = []
    x_nc = []
    y_nc = []
    y_centre = int((249 - 65)/Rat)
    x_centre = int((399 - 100)/Rat)
    radius_c = int(55/Rat) #radius of cicle including clearance
    radius = int(40/Rat)
    map_obs1 = np.copy(map_def) # a deep copy #chnage this to map_obs1
    for x in range(int(240/Rat),int(360/Rat)):
        for y in range(int(120/Rat), int(240/Rat)):
            if (np.sqrt((x-x_centre)**2 + (y-y_centre)**2)) < radius_c:
                map_obs1[y, x,:] = -1 #obstacle space updated as -1
                x_c.append(x) #to be used for plotting
                y_c.append(y)
                allp_map.append([x,y]) #to be used for visualisation on pygame
            if (np.sqrt((x-x_centre)**2 + (y-y_centre)**2)) < radius:
                x_nc.append(x) #list of obstacle without clearance
                y_nc.append(y)

# %%
import matplotlib.pyplot as plt
plt.scatter(x_c, y_c)
# plt.scatter(x_h, y_h)
# plt.scatter(x_t1, y_t1)
# plt.scatter(x_t2, y_t2)
plt.axis([0, 800, 0, 500])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Triangles

# %%
def triang_obs():
    global x_t1, y_t1, x_t1_nc, y_t1_nc, map_obs2, x_t2_nc, y_t2_nc, x_t2, y_t2, allp_map, Rat
    x_t1 = []
    y_t1 = []
    x_t2 = []
    y_t2 = []
    map_obs2 = np.copy(map_obs1)
    for x in range(int(170/Rat)):
        for y in range(int(40*Rat),int(240/Rat)):
            if (y - (6/7)*x - ((779/7) + 15)/Rat)<=0 and (y - (-85/69)*x - ((15880/69) -18)/Rat)>=0 and (y - (-16/5)*x - ((2169/5) +25)/Rat)<=0 :
                map_obs2[y,x,:] = -1
                x_t1.append(x)
                y_t1.append(y)
                allp_map.append([x,y])
            if (y - (6/7)*x - ((779/7) - 15)/Rat)>=0 and (y - (-85/69)*x - ((15880/69) -18)/Rat)>=0 and (y - (25/79)*x - ((13661/79) +15)/Rat)<=0:
                map_obs2[y,x,:] = -1
                x_t2.append(x)
                y_t2.append(y)
                allp_map.append([x,y])

# %%
import matplotlib.pyplot as plt
#plt.scatter(x_c, y_c)
# plt.scatter(x_h, y_h)
plt.scatter(x_t1, y_t1)
plt.scatter(x_t2, y_t2)
plt.axis([0, 400, 0, 250])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Hexagon

# %%
def hex_obs():
    global map_obs4, x_h, y_h, x_h_nc, y_h_nc, allp_map
    x_h = []
    y_h = []
    map_obs4 = np.copy(map_obs2)
    for x in range(int(148/Rat), int(252/Rat)):
        for y in range(int(30/Rat),int(165/Rat)):
            if (y - (5/8)*x + 81/Rat)>=0 and (y + (5/8)*x - 281/Rat)<=0 and (y - (5/8)*x - 31/Rat)<=0 and (y + (5/8)*x - 169/Rat)>=0 and (x - 249/Rat)<=0 and (x - 150/Rat)>=0:
                map_obs4[y,x,:] = -1
                x_h.append(x)
                y_h.append(y)
                allp_map.append([x,y])

# %%
hex_obs()

# %%
import matplotlib.pyplot as plt
plt.scatter(x_c, y_c)
plt.scatter(x_h, y_h)
plt.scatter(x_t1, y_t1)
plt.scatter(x_t2, y_t2)
plt.axis([0, 800, 0, 500])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The main algorithm

# %% [markdown]
# Data structure

# %%
class Node:
    def __init__(self, node_id, node_loc, parent_id, c2c , c2g):
        self.parent_id = parent_id #
        self.node_id = node_id #unique node id for each node
        self.node_loc = node_loc ## [y,x,angle]
        self.c2c= round(c2c,0)
        self.c2g=round(c2g,2)
        self.total_cost = round(c2c+c2g,2)

# %%
def pop(Closed_list, Open_list, All_list):
    dat = Open_list.get()
    #dat[0] is c2c+c2g, dat[1] is Node_id--> starts from 1, list starts from 0 
    Closed_list.append(All_list[dat[1]-1]) #indexing the node from the all_list  
    ##check for goal
    print('closed list updated')
    if All_list[dat[1]-1].node_loc in goal_list:
        print('this will be done at', All_list[dat[1]-1].node_loc )
        return "Goal found"
    return All_list[dat[1]-1]

# %% [markdown]
# Cost Dictionary

# %%
cost_direction = {'S': 1, 'D': 1}

# %% [markdown]
# Parameter update

# %%
def param(All_list, Open_list, map_obs4, cost_dir, n_c, n_d,ang, node):
     id = All_list[-1].node_id + 1
     map_obs4[n_c,n_d,int(ang/30)] = id  ## id is updated in map
     c2_g=c2g([n_c,n_d],goal_location[0:2])
     c2c=node.c2c+cost_dir
     cost = c2c+c2_g  #cost_dir is a dictionary
     parent = node.node_id
     loc = [n_c, n_d, int(ang/30)]
     # print('node at id', id, 'cost is', cost, 'loc', loc)
     All_list.append(Node(id, loc, parent, c2c,c2_g)) ## node is created
     tup_new = [cost, id]
     Open_list.put(tup_new) ## list of [cost, id] ###gives the [cost,id] in priority queue open list

# %% [markdown]
# List cost update function

# %% [markdown]
# All cost needs to be rounded off to 2 due to euclidean distance

# %%
def cost_update(nod, n_c ,n_d, ang, All_list,  Closed_list, Open_list, map_obs4, cost_dir):
     index = int(map_obs4[n_c, n_d, int(ang/30)])
     if round((nod.c2c + cost_dir),1)< round(All_list[index-1].c2c,1): #since index/node_id is starting from 1
            All_list[index-1].c2c = round((nod.c2c + cost_dir),1)
            All_list[index-1].parent_id = nod.node_id
            # print('updated cost of node', index, 'is', All_list[index-1].cost)
            for i in Closed_list:
                if i.node_id ==index:
                        i.c2c = round((nod.c2c + cost_dir),1)
                        i.parent_id = nod.node_id
            if Open_list.qsize() > 0:
                for j in Open_list.queue:
                    if j[1] ==index:
                            j[0] = round((nod.c2c + cost_dir),1)
                            # i.parent_id = nod.node_id

# %% [markdown]
# Check if goal function

# %%
# def check_if_goal(goal_loc, A_list, go_cost):
#     # print('checking goal')
#     if goal_loc==A_list[-1].node_loc:
#         go_cost = A_list[-1].cost #updates the goal cost
#         print('goal cost is', go_cost)
#         return go_cost
#     else:
#         return None

# %%
def move_zero(node, All_list, Open_list, k):
    a,b, node_k =node.node_loc
    angle=node_k*30
    ang=(angle+k*30)%360
    c= a + (L*np.sin(ang*(np.pi/180)))/Rat #needs to be according to the matrix
    d= b + (L*np.cos(ang*(np.pi/180)))/Rat
    n_c, n_d=thres_round(c,d)
    print(n_c, n_d, ang)
    if (9/Rat)<=(n_c/Rat)<=(239/Rat) and (9/Rat)<=n_d<=(389/Rat): 
        if map_obs4[n_c,n_d,int(ang/30)]==-2:
            param(All_list, Open_list, map_obs4, cost_direction['S'], n_c, n_d, ang, node) 
            print('node created with id', All_list[-1].node_id)
            return print('node created at', All_list[-1].node_loc)
            
        elif map_obs4[n_c,n_d, int(ang/30)]==-1:
            print('Obstacle space')
            return None
        
        else:
            print('Node exists, checking cost...')
            cost_update(node, n_c ,n_d,ang, All_list,  Closed_list, Open_list, map_obs4, cost_direction['S'])  
            return None
    else:
        return None

# %%
def thres_round(c,d):
    # Rat=0.5
    n_c=np.round(c,0)
    n_d=np.round(d,0)

    return int(n_c),int(n_d)

# %%
def movement(node, All_list, Open_list):
    move_zero(node, All_list, Open_list,0)
    print('move 0')
    move_zero(node, All_list, Open_list,-1)
    print('move 1')
    move_zero(node, All_list, Open_list,-2)
    print('move 2')
    move_zero(node, All_list, Open_list,1)
    print('move 3')
    move_zero(node, All_list, Open_list,2)
    print('move 4')

# %% [markdown]
# considering a radius of 2 for now:

# %%
#passed input is as per the user
def goal_space(goal_x, goal_y, k):
    centre_x = goal_x
    centre_y = goal_y
    goal_list = []
    for i in range(goal_x-3,goal_x+3):
        for j in range(goal_y-3, goal_y+3):
            if (i-centre_x)**2 + (j-centre_y)**2<=4:
                goal_list.append([j,i,k])
    return goal_list 
    #output is as per the matrix

# %%
# def backtrack(A_list, x, y):
#     ind = int(map_obs4[goal_location[0], goal_location[1]])
#     x.append(A_list[ind-1].node_loc[0])
#     y.append(A_list[ind-1].node_loc[1])
#     id = A_list[ind-1].parent_id
#     while(id>0):
#         x.append(A_list[id-1].node_loc[0])
#         y.append(A_list[id-1].node_loc[1])
#         id = A_list[id - 1].parent_id

# %%
def c2g(initial, final):
    
    return np.round(np.linalg.norm(np.array(initial)-np.array(final)),2)

# %% [markdown]
# x,y-world coordinate
# x,y,k--- angle in terms of degrees
# k --- 0,11
# angle =k*30

# %%
def initial():
    global All_list, Closed_list, goal_location, Open_list, allp_map, goal_list
    allp_map = []
    All_list = []
    Closed_list = []
    goal_list = []
    first_node_id = 1
    start_cords_x = 10##int(input("please enter the starting x coordinate: "))
    start_cords_y = 10##int(input("please enter the starting y coordinate: "))
    start_angle=0 ##int(input("please enter the starting angle"))
    start_k=int(start_angle/30)
    # if start_cords_x<1 or start_cords_x>400 or start_cords_y<1 or start_cords_y>400:
    #     print("Either wrong input or the start node is in obstacle space")
    #     exit(0)
    # else:
    #     node_loc = [start_cords_y-1, start_cords_x-1]
    start_location = [(start_cords_y-1)/Rat, (start_cords_x-1)/Rat, start_k]
    goal_cords_x = 141##int(input("please enter the goal x coordinate: "))
    goal_cords_y = 101 ##int(input("please enter the goal y coordinate: "))
    goal_angle=60 ##int(input("please enter the goal angle"))
    goal_k=int(goal_angle/30)
    # if goal_cords_x<1 or goal_cords_x>400 or goal_cords_y<1 or goal_cords_y>400:
    #     print("Either wrong input or the goal node is in obstacle space")
    #     exit(0)
    # else:
    #     goal_location = [goal_cords_y-1, goal_cords_x-1] ### change
    goal_location = [(goal_cords_y-1)/Rat, (goal_cords_x-1)/Rat,goal_k]
    goal_list = goal_space(goal_cords_x-1, goal_cords_y-1, goal_k)
    map()
    circle_obs()
    triang_obs()
    hex_obs()
    # if map_obs4[start_cords_y-1, start_cords_x-1]==-1 or map_obs4[goal_cords_y-1, goal_cords_x-1]==-1:
    #     print("start or goal node in obstacle space")
    #     exit(0)
    # else:
    map_obs4[start_cords_y-1, start_cords_x-1, start_k] = first_node_id
    first_parent_id = 0
    initial_c2g=c2g(start_location[0:2], goal_location[0:2])
    first_cost = 0+initial_c2g
    All_list.append(Node(first_node_id, start_location, first_parent_id,0,initial_c2g))
    tup = [first_cost, first_node_id] # just the cost and node id, access the node using all visited and node id
    Open_list = PriorityQueue()
    Open_list.put(tup)

# %%
Rat = 1 #unit per node
L=1 #can be from 1 to 10
initial()

# %%
goal_list
# Out:
# [[100, 138, 2],
#  [99, 139, 2],
#  [100, 139, 2],
#  [101, 139, 2],
#  [98, 140, 2],
#  [99, 140, 2],
#  [100, 140, 2],
#  [101, 140, 2],
#  [102, 140, 2],
#  [99, 141, 2],
#  [100, 141, 2],
#  [101, 141, 2],
#  [100, 142, 2]]

# %%
import matplotlib.pyplot as plt
plt.scatter(x_c, y_c)
plt.scatter(x_h, y_h)
plt.scatter(x_t1, y_t1)
plt.scatter(x_t2, y_t2)
plt.axis([0, 400, 0, 250])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
map_obs4[100,140,:]
# Out:
# array([-2., -2., -2., -2., -2., -2., -2., -2., -2., -2., -2., -2.])

# %%
np.shape(np.where(map_obs4==-1))
# Out:
# (3, 215280)

# %% [markdown]
# Take the input from user

# %%
##goal_cost = np.inf
while(1):
    if (Open_list.qsize()>0):
        

        print('inside while')
        node =pop(Closed_list, Open_list, All_list)
        print('all list length is', len(All_list))
        if type(node) == str:
            print('done')
            break
        else:
            print('popped')

        # print('closed list', len(Closed_list))
        # print('openlist', len(Open_list))
            movement(node, All_list, Open_list)
            # print('check is', check)
        #     if(check!=None):
        #         print('mila na')
        #         goal_cost = All_list[int(map_obs4[goal_location[0],goal_location[1]]-1)].cost

        #         print('goal cost is', goal_cost)
        # else:
        #     print('cost exceeded')
        #     break
    
    else:
        print('open list empty')
        break
# Out:
# inside while
# closed list updated
# all list length is 1
# popped
# 9 10 0
# node created with id 2
# node created at [9, 10, 0]
# move 0
# 8 10 330
# move 1
# 8 10 300
# move 2
# 10 10 30
# node created with id 3
# node created at [10, 10, 1]
# move 3
# 10 10 60
# node created with id 4
# node created at [10, 10, 2]
# move 4
# inside while
# closed list updated
# all list length is 4
# popped
# 10 11 30
# node created with id 5
# node created at [10, 11, 1]
# move 0
# 10 11 0
# node created with id 6
# node created at [10, 11, 0]
# move 1
# 10 11 330
# node created with id 7
# node created at [10, 11, 11]
# move 2
# 11 10 60
# node created with id 8
# node created at [11, 10, 2]
# move 3
# 11 10 90
# node created with id 9
# node created at [11, 10, 3]
# move 4
# inside while
# closed list updated
# all list length is 9
# popped
# 11 10 60
# Node exists, checking cost...
# move 0
# 10 11 30
# Node exists, checking cost...
# move 1
# 10 11 0
# Node exists, checking cost...
# move 2
# 11 10 90
# Node exists, checking cost...
# move 3
# 11 10 120
# node created with id 10
# node created at [11, 10, 4]
# move 4
# inside while
# closed list updated
# all list length is 10
# popped
# 10 12 30
# node created with id 11
# node created at [10, 12, 1]
# move 0
# 10 12 0
# node created with id 12
# node created at [10, 12, 0]
# move 1
# 10 12 330
# node created with id 13
# node created at [10, 12, 11]
# move 2
# 11 12 60
# node created with id 14
# node created at [11, 12, 2]
# move 3
# 11 11 90
# node created with id 15
# node created at [11, 11, 3]
# move 4
# inside while
# closed list updated
# all list length is 15
# popped
# 12 12 60
# node created with id 16
# node created at [12, 12, 2]
# move 0
# 12 13 30
# node created with id 17
# node created at [12, 13, 1]
# move 1
# 11 13 0
# node created with id 18
# node created at [11, 13, 0]
# move 2
# 12 12 90
# node created with id 19
# node created at [12, 12, 3]
# move 3
# 12 12 120
# node created with id 20
# node created at [12, 12, 4]
# move 4
# inside while
# closed list updated
# all list length is 20
# popped
# 12 14 30
# node created with id 21
# node created at [12, 14, 1]
# move 0
# 12 14 0
# node created with id 22
# node created at [12, 14, 0]
# move 1
# 12 14 330
# node created with id 23
# node created at [12, 14, 11]
# move 2
# 13 14 60
# node created with id 24
# node created at [13, 14, 2]
# move 3
# 13 13 90
# node created with id 25
# node created at [13, 13, 3]
# move 4
# inside while
# closed list updated
# all list length is 25
# popped
# 14 14 60
# node created with id 26
# node created at [14, 14, 2]
# move 0
# 14 15 30
# node created with id 27
# node created at [14, 15, 1]
# move 1
# 13 15 0
# node created with id 28
# node created at [13, 15, 0]
# move 2
# 14 14 90
# node created with id 29
# node created at [14, 14, 3]
# move 3
# 14 14 120
# node created with id 30
# node created at [14, 14, 4]
# move 4
# inside while
# closed list updated
# all list length is 30
# popped
# 14 16 30
# node created with id 31
# node created at [14, 16, 1]
# move 0
# 14 16 0
# node created with id 32
# node created at [14, 16, 0]
# move 1
# 14 16 330
# node created with id 33
# node created at [14, 16, 11]
# move 2
# 15 16 60
# node created with id 34
# node created at [15, 16, 2]
# move 3
# 15 15 90
# node created with id 35
# node created at [15, 15, 3]
# move 4
# inside while
# closed list updated
# all list length is 35
# popped
# 16 16 60
# node created with id 36
# node created at [16, 16, 2]
# move 0
# 16 17 30
# node created with id 37
# node created at [16, 17, 1]
# move 1
# 15 17 0
# node created with id 38
# node created at [15, 17, 0]
# move 2
# 16 16 90
# node created with id 39
# node created at [16, 16, 3]
# move 3
# 16 16 120
# node created with id 40
# node created at [16, 16, 4]
# move 4
# inside while
# closed list updated
# all list length is 40
# popped
# 16 18 30
# node created with id 41
# node created at [16, 18, 1]
# move 0
# 16 18 0
# node created with id 42
# node created at [16, 18, 0]
# move 1
# 16 18 330
# node created with id 43
# node created at [16, 18, 11]
# move 2
# 17 18 60
# node created with id 44
# node created at [17, 18, 2]
# move 3
# 17 17 90
# node created with id 45
# node created at [17, 17, 3]
# move 4
# inside while
# closed list updated
# all list length is 45
# popped
# 18 18 60
# node created with id 46
# node created at [18, 18, 2]
# move 0
# 18 19 30
# node created with id 47
# node created at [18, 19, 1]
# move 1
# 17 19 0
# node created with id 48
# node created at [17, 19, 0]
# move 2
# 18 18 90
# node created with id 49
# node created at [18, 18, 3]
# move 3
# 18 18 120
# node created with id 50
# node created at [18, 18, 4]
# move 4
# inside while
# closed list updated
# all list length is 50
# popped
# 18 20 30
# node created with id 51
# node created at [18, 20, 1]
# move 0
# 18 20 0
# node created with id 52
# node created at [18, 20, 0]
# move 1
# 18 20 330
# node created with id 53
# node created at [18, 20, 11]
# move 2
# 19 20 60
# node created with id 54
# node created at [19, 20, 2]
# move 3
# 19 19 90
# node created with id 55
# node created at [19, 19, 3]
# move 4
# inside while
# closed list updated
# all list length is 55
# popped
# 20 20 60
# node created with id 56
# node created at [20, 20, 2]
# move 0
# 20 21 30
# node created with id 57
# node created at [20, 21, 1]
# move 1
# 19 21 0
# node created with id 58
# node created at [19, 21, 0]
# move 2
# 20 20 90
# node created with id 59
# node created at [20, 20, 3]
# move 3
# 20 20 120
# node created with id 60
# node created at [20, 20, 4]
# move 4
# inside while
# closed list updated
# all list length is 60
# popped
# 20 22 30
# node created with id 61
# node created at [20, 22, 1]
# move 0
# 20 22 0
# node created with id 62
# node created at [20, 22, 0]
# move 1
# 20 22 330
# node created with id 63
# node created at [20, 22, 11]
# move 2
# 21 22 60
# node created with id 64
# node created at [21, 22, 2]
# move 3
# 21 21 90
# node created with id 65
# node created at [21, 21, 3]
# move 4
# inside while
# closed list updated
# all list length is 65
# popped
# 22 22 60
# node created with id 66
# node created at [22, 22, 2]
# move 0
# 22 23 30
# node created with id 67
# node created at [22, 23, 1]
# move 1
# 21 23 0
# node created with id 68
# node created at [21, 23, 0]
# move 2
# 22 22 90
# node created with id 69
# node created at [22, 22, 3]
# move 3
# 22 22 120
# node created with id 70
# node created at [22, 22, 4]
# move 4
# inside while
# closed list updated
# all list length is 70
# popped
# 22 24 30
# node created with id 71
# node created at [22, 24, 1]
# move 0
# 22 24 0
# node created with id 72
# node created at [22, 24, 0]
# move 1
# 22 24 330
# node created with id 73
# node created at [22, 24, 11]
# move 2
# 23 24 60
# node created with id 74
# node created at [23, 24, 2]
# move 3
# 23 23 90
# node created with id 75
# node created at [23, 23, 3]
# move 4
# inside while
# closed list updated
# all list length is 75
# popped
# 24 24 60
# node created with id 76
# node created at [24, 24, 2]
# move 0
# 24 25 30
# node created with id 77
# node created at [24, 25, 1]
# move 1
# 23 25 0
# node created with id 78
# node created at [23, 25, 0]
# move 2
# 24 24 90
# node created with id 79
# node created at [24, 24, 3]
# move 3
# 24 24 120
# node created with id 80
# node created at [24, 24, 4]
# move 4
# inside while
# closed list updated
# all list length is 80
# popped
# 24 26 30
# node created with id 81
# node created at [24, 26, 1]
# move 0
# 24 26 0
# node created with id 82
# node created at [24, 26, 0]
# move 1
# 24 26 330
# node created with id 83
# node created at [24, 26, 11]
# move 2
# 25 26 60
# node created with id 84
# node created at [25, 26, 2]
# move 3
# 25 25 90
# node created with id 85
# node created at [25, 25, 3]
# move 4
# inside while
# closed list updated
# all list length is 85
# popped
# 26 26 60
# node created with id 86
# node created at [26, 26, 2]
# move 0
# 26 27 30
# node created with id 87
# node created at [26, 27, 1]
# move 1
# 25 27 0
# node created with id 88
# node created at [25, 27, 0]
# move 2
# 26 26 90
# node created with id 89
# node created at [26, 26, 3]
# move 3
# 26 26 120
# node created with id 90
# node created at [26, 26, 4]
# move 4
# inside while
# closed list updated
# all list length is 90
# popped
# 26 28 30
# node created with id 91
# node created at [26, 28, 1]
# move 0
# 26 28 0
# node created with id 92
# node created at [26, 28, 0]
# move 1
# 26 28 330
# node created with id 93
# node created at [26, 28, 11]
# move 2
# 27 28 60
# node created with id 94
# node created at [27, 28, 2]
# move 3
# 27 27 90
# node created with id 95
# node created at [27, 27, 3]
# move 4
# inside while
# closed list updated
# all list length is 95
# popped
# 28 28 60
# node created with id 96
# node created at [28, 28, 2]
# move 0
# 28 29 30
# node created with id 97
# node created at [28, 29, 1]
# move 1
# 27 29 0
# node created with id 98
# node created at [27, 29, 0]
# move 2
# 28 28 90
# node created with id 99
# node created at [28, 28, 3]
# move 3
# 28 28 120
# node created with id 100
# node created at [28, 28, 4]
# move 4
# inside while
# closed list updated
# all list length is 100
# popped
# 28 30 30
# node created with id 101
# node created at [28, 30, 1]
# move 0
# 28 30 0
# node created with id 102
# node created at [28, 30, 0]
# move 1
# 28 30 330
# node created with id 103
# node created at [28, 30, 11]
# move 2
# 29 30 60
# node created with id 104
# node created at [29, 30, 2]
# move 3
# 29 29 90
# node created with id 105
# node created at [29, 29, 3]
# move 4
# inside while
# closed list updated
# all list length is 105
# popped
# 30 30 60
# node created with id 106
# node created at [30, 30, 2]
# move 0
# 30 31 30
# node created with id 107
# node created at [30, 31, 1]
# move 1
# 29 31 0
# node created with id 108
# node created at [29, 31, 0]
# move 2
# 30 30 90
# node created with id 109
# node created at [30, 30, 3]
# move 3
# 30 30 120
# node created with id 110
# node created at [30, 30, 4]
# move 4
# inside while
# closed list updated
# all list length is 110
# popped
# 30 32 30
# node created with id 111
# node created at [30, 32, 1]
# move 0
# 30 32 0
# node created with id 112
# node created at [30, 32, 0]
# move 1
# 30 32 330
# node created with id 113
# node created at [30, 32, 11]
# move 2
# 31 32 60
# node created with id 114
# node created at [31, 32, 2]
# move 3
# 31 31 90
# node created with id 115
# node created at [31, 31, 3]
# move 4
# inside while
# closed list updated
# all list length is 115
# popped
# 32 32 60
# node created with id 116
# node created at [32, 32, 2]
# move 0
# 32 33 30
# node created with id 117
# node created at [32, 33, 1]
# move 1
# 31 33 0
# node created with id 118
# node created at [31, 33, 0]
# move 2
# 32 32 90
# node created with id 119
# node created at [32, 32, 3]
# move 3
# 32 32 120
# node created with id 120
# node created at [32, 32, 4]
# move 4
# inside while
# closed list updated
# all list length is 120
# popped
# 32 34 30
# node created with id 121
# node created at [32, 34, 1]
# move 0
# 32 34 0
# node created with id 122
# node created at [32, 34, 0]
# move 1
# 32 34 330
# node created with id 123
# node created at [32, 34, 11]
# move 2
# 33 34 60
# node created with id 124
# node created at [33, 34, 2]
# move 3
# 33 33 90
# node created with id 125
# node created at [33, 33, 3]
# move 4
# inside while
# closed list updated
# all list length is 125
# popped
# 34 34 60
# node created with id 126
# node created at [34, 34, 2]
# move 0
# 34 35 30
# node created with id 127
# node created at [34, 35, 1]
# move 1
# 33 35 0
# node created with id 128
# node created at [33, 35, 0]
# move 2
# 34 34 90
# node created with id 129
# node created at [34, 34, 3]
# move 3
# 34 34 120
# node created with id 130
# node created at [34, 34, 4]
# move 4
# inside while
# closed list updated
# all list length is 130
# popped
# 34 36 30
# node created with id 131
# node created at [34, 36, 1]
# move 0
# 34 36 0
# node created with id 132
# node created at [34, 36, 0]
# move 1
# 34 36 330
# node created with id 133
# node created at [34, 36, 11]
# move 2
# 35 36 60
# node created with id 134
# node created at [35, 36, 2]
# move 3
# 35 35 90
# node created with id 135
# node created at [35, 35, 3]
# move 4
# inside while
# closed list updated
# all list length is 135
# popped
# 36 36 60
# node created with id 136
# node created at [36, 36, 2]
# move 0
# 36 37 30
# node created with id 137
# node created at [36, 37, 1]
# move 1
# 35 37 0
# node created with id 138
# node created at [35, 37, 0]
# move 2
# 36 36 90
# node created with id 139
# node created at [36, 36, 3]
# move 3
# 36 36 120
# node created with id 140
# node created at [36, 36, 4]
# move 4
# inside while
# closed list updated
# all list length is 140
# popped
# 36 38 30
# node created with id 141
# node created at [36, 38, 1]
# move 0
# 36 38 0
# node created with id 142
# node created at [36, 38, 0]
# move 1
# 36 38 330
# node created with id 143
# node created at [36, 38, 11]
# move 2
# 37 38 60
# node created with id 144
# node created at [37, 38, 2]
# move 3
# 37 37 90
# node created with id 145
# node created at [37, 37, 3]
# move 4
# inside while
# closed list updated
# all list length is 145
# popped
# 38 38 60
# node created with id 146
# node created at [38, 38, 2]
# move 0
# 38 39 30
# node created with id 147
# node created at [38, 39, 1]
# move 1
# 37 39 0
# node created with id 148
# node created at [37, 39, 0]
# move 2
# 38 38 90
# node created with id 149
# node created at [38, 38, 3]
# move 3
# 38 38 120
# node created with id 150
# node created at [38, 38, 4]
# move 4
# inside while
# closed list updated
# all list length is 150
# popped
# 38 40 30
# node created with id 151
# node created at [38, 40, 1]
# move 0
# 38 40 0
# node created with id 152
# node created at [38, 40, 0]
# move 1
# 38 40 330
# node created with id 153
# node created at [38, 40, 11]
# move 2
# 39 40 60
# node created with id 154
# node created at [39, 40, 2]
# move 3
# 39 39 90
# node created with id 155
# node created at [39, 39, 3]
# move 4
# inside while
# closed list updated
# all list length is 155
# popped
# 40 40 60
# node created with id 156
# node created at [40, 40, 2]
# move 0
# 40 41 30
# node created with id 157
# node created at [40, 41, 1]
# move 1
# 39 41 0
# node created with id 158
# node created at [39, 41, 0]
# move 2
# 40 40 90
# node created with id 159
# node created at [40, 40, 3]
# move 3
# 40 40 120
# node created with id 160
# node created at [40, 40, 4]
# move 4
# inside while
# closed list updated
# all list length is 160
# popped
# 40 42 30
# node created with id 161
# node created at [40, 42, 1]
# move 0
# 40 42 0
# node created with id 162
# node created at [40, 42, 0]
# move 1
# 40 42 330
# node created with id 163
# node created at [40, 42, 11]
# move 2
# 41 42 60
# node created with id 164
# node created at [41, 42, 2]
# move 3
# 41 41 90
# node created with id 165
# node created at [41, 41, 3]
# move 4
# inside while
# closed list updated
# all list length is 165
# popped
# 42 42 60
# node created with id 166
# node created at [42, 42, 2]
# move 0
# 42 43 30
# node created with id 167
# node created at [42, 43, 1]
# move 1
# 41 43 0
# node created with id 168
# node created at [41, 43, 0]
# move 2
# 42 42 90
# node created with id 169
# node created at [42, 42, 3]
# move 3
# 42 42 120
# node created with id 170
# node created at [42, 42, 4]
# move 4
# inside while
# closed list updated
# all list length is 170
# popped
# 42 44 30
# node created with id 171
# node created at [42, 44, 1]
# move 0
# 42 44 0
# node created with id 172
# node created at [42, 44, 0]
# move 1
# 42 44 330
# node created with id 173
# node created at [42, 44, 11]
# move 2
# 43 44 60
# node created with id 174
# node created at [43, 44, 2]
# move 3
# 43 43 90
# node created with id 175
# node created at [43, 43, 3]
# move 4
# inside while
# closed list updated
# all list length is 175
# popped
# 44 44 60
# node created with id 176
# node created at [44, 44, 2]
# move 0
# 44 45 30
# node created with id 177
# node created at [44, 45, 1]
# move 1
# 43 45 0
# node created with id 178
# node created at [43, 45, 0]
# move 2
# 44 44 90
# node created with id 179
# node created at [44, 44, 3]
# move 3
# 44 44 120
# node created with id 180
# node created at [44, 44, 4]
# move 4
# inside while
# closed list updated
# all list length is 180
# popped
# 44 46 30
# node created with id 181
# node created at [44, 46, 1]
# move 0
# 44 46 0
# node created with id 182
# node created at [44, 46, 0]
# move 1
# 44 46 330
# node created with id 183
# node created at [44, 46, 11]
# move 2
# 45 46 60
# node created with id 184
# node created at [45, 46, 2]
# move 3
# 45 45 90
# node created with id 185
# node created at [45, 45, 3]
# move 4
# inside while
# closed list updated
# all list length is 185
# popped
# 46 46 60
# node created with id 186
# node created at [46, 46, 2]
# move 0
# 46 47 30
# node created with id 187
# node created at [46, 47, 1]
# move 1
# 45 47 0
# node created with id 188
# node created at [45, 47, 0]
# move 2
# 46 46 90
# node created with id 189
# node created at [46, 46, 3]
# move 3
# 46 46 120
# node created with id 190
# node created at [46, 46, 4]
# move 4
# inside while
# closed list updated
# all list length is 190
# popped
# 46 48 30
# node created with id 191
# node created at [46, 48, 1]
# move 0
# 46 48 0
# node created with id 192
# node created at [46, 48, 0]
# move 1
# 46 48 330
# node created with id 193
# node created at [46, 48, 11]
# move 2
# 47 48 60
# node created with id 194
# node created at [47, 48, 2]
# move 3
# 47 47 90
# node created with id 195
# node created at [47, 47, 3]
# move 4
# inside while
# closed list updated
# all list length is 195
# popped
# 48 48 60
# node created with id 196
# node created at [48, 48, 2]
# move 0
# 48 49 30
# node created with id 197
# node created at [48, 49, 1]
# move 1
# 47 49 0
# node created with id 198
# node created at [47, 49, 0]
# move 2
# 48 48 90
# node created with id 199
# node created at [48, 48, 3]
# move 3
# 48 48 120
# node created with id 200
# node created at [48, 48, 4]
# move 4
# inside while
# closed list updated
# all list length is 200
# popped
# 48 50 30
# node created with id 201
# node created at [48, 50, 1]
# move 0
# 48 50 0
# node created with id 202
# node created at [48, 50, 0]
# move 1
# 48 50 330
# node created with id 203
# node created at [48, 50, 11]
# move 2
# 49 50 60
# node created with id 204
# node created at [49, 50, 2]
# move 3
# 49 49 90
# node created with id 205
# node created at [49, 49, 3]
# move 4
# inside while
# closed list updated
# all list length is 205
# popped
# 50 50 60
# node created with id 206
# node created at [50, 50, 2]
# move 0
# 50 51 30
# node created with id 207
# node created at [50, 51, 1]
# move 1
# 49 51 0
# node created with id 208
# node created at [49, 51, 0]
# move 2
# 50 50 90
# node created with id 209
# node created at [50, 50, 3]
# move 3
# 50 50 120
# node created with id 210
# node created at [50, 50, 4]
# move 4
# inside while
# closed list updated
# all list length is 210
# popped
# 50 52 30
# node created with id 211
# node created at [50, 52, 1]
# move 0
# 50 52 0
# node created with id 212
# node created at [50, 52, 0]
# move 1
# 50 52 330
# node created with id 213
# node created at [50, 52, 11]
# move 2
# 51 52 60
# node created with id 214
# node created at [51, 52, 2]
# move 3
# 51 51 90
# node created with id 215
# node created at [51, 51, 3]
# move 4
# inside while
# closed list updated
# all list length is 215
# popped
# 52 52 60
# node created with id 216
# node created at [52, 52, 2]
# move 0
# 52 53 30
# node created with id 217
# node created at [52, 53, 1]
# move 1
# 51 53 0
# node created with id 218
# node created at [51, 53, 0]
# move 2
# 52 52 90
# node created with id 219
# node created at [52, 52, 3]
# move 3
# 52 52 120
# node created with id 220
# node created at [52, 52, 4]
# move 4
# inside while
# closed list updated
# all list length is 220
# popped
# 52 54 30
# node created with id 221
# node created at [52, 54, 1]
# move 0
# 52 54 0
# node created with id 222
# node created at [52, 54, 0]
# move 1
# 52 54 330
# node created with id 223
# node created at [52, 54, 11]
# move 2
# 53 54 60
# node created with id 224
# node created at [53, 54, 2]
# move 3
# 53 53 90
# node created with id 225
# node created at [53, 53, 3]
# move 4
# inside while
# closed list updated
# all list length is 225
# popped
# 54 54 60
# node created with id 226
# node created at [54, 54, 2]
# move 0
# 54 55 30
# node created with id 227
# node created at [54, 55, 1]
# move 1
# 53 55 0
# node created with id 228
# node created at [53, 55, 0]
# move 2
# 54 54 90
# node created with id 229
# node created at [54, 54, 3]
# move 3
# 54 54 120
# node created with id 230
# node created at [54, 54, 4]
# move 4
# inside while
# closed list updated
# all list length is 230
# popped
# 54 56 30
# node created with id 231
# node created at [54, 56, 1]
# move 0
# 54 56 0
# node created with id 232
# node created at [54, 56, 0]
# move 1
# 54 56 330
# node created with id 233
# node created at [54, 56, 11]
# move 2
# 55 56 60
# node created with id 234
# node created at [55, 56, 2]
# move 3
# 55 55 90
# node created with id 235
# node created at [55, 55, 3]
# move 4
# inside while
# closed list updated
# all list length is 235
# popped
# 56 56 60
# node created with id 236
# node created at [56, 56, 2]
# move 0
# 56 57 30
# node created with id 237
# node created at [56, 57, 1]
# move 1
# 55 57 0
# node created with id 238
# node created at [55, 57, 0]
# move 2
# 56 56 90
# node created with id 239
# node created at [56, 56, 3]
# move 3
# 56 56 120
# node created with id 240
# node created at [56, 56, 4]
# move 4
# inside while
# closed list updated
# all list length is 240
# popped
# 56 58 30
# node created with id 241
# node created at [56, 58, 1]
# move 0
# 56 58 0
# node created with id 242
# node created at [56, 58, 0]
# move 1
# 56 58 330
# node created with id 243
# node created at [56, 58, 11]
# move 2
# 57 58 60
# node created with id 244
# node created at [57, 58, 2]
# move 3
# 57 57 90
# node created with id 245
# node created at [57, 57, 3]
# move 4
# inside while
# closed list updated
# all list length is 245
# popped
# 58 58 60
# node created with id 246
# node created at [58, 58, 2]
# move 0
# 58 59 30
# node created with id 247
# node created at [58, 59, 1]
# move 1
# 57 59 0
# node created with id 248
# node created at [57, 59, 0]
# move 2
# 58 58 90
# node created with id 249
# node created at [58, 58, 3]
# move 3
# 58 58 120
# node created with id 250
# node created at [58, 58, 4]
# move 4
# inside while
# closed list updated
# all list length is 250
# popped
# 58 60 30
# node created with id 251
# node created at [58, 60, 1]
# move 0
# 58 60 0
# node created with id 252
# node created at [58, 60, 0]
# move 1
# 58 60 330
# node created with id 253
# node created at [58, 60, 11]
# move 2
# 59 60 60
# node created with id 254
# node created at [59, 60, 2]
# move 3
# 59 59 90
# node created with id 255
# node created at [59, 59, 3]
# move 4
# inside while
# closed list updated
# all list length is 255
# popped
# 60 60 60
# node created with id 256
# node created at [60, 60, 2]
# move 0
# 60 61 30
# node created with id 257
# node created at [60, 61, 1]
# move 1
# 59 61 0
# node created with id 258
# node created at [59, 61, 0]
# move 2
# 60 60 90
# node created with id 259
# node created at [60, 60, 3]
# move 3
# 60 60 120
# node created with id 260
# node created at [60, 60, 4]
# move 4
# inside while
# closed list updated
# all list length is 260
# popped
# 60 62 30
# node created with id 261
# node created at [60, 62, 1]
# move 0
# 60 62 0
# node created with id 262
# node created at [60, 62, 0]
# move 1
# 60 62 330
# node created with id 263
# node created at [60, 62, 11]
# move 2
# 61 62 60
# node created with id 264
# node created at [61, 62, 2]
# move 3
# 61 61 90
# node created with id 265
# node created at [61, 61, 3]
# move 4
# inside while
# closed list updated
# all list length is 265
# popped
# 62 62 60
# node created with id 266
# node created at [62, 62, 2]
# move 0
# 62 63 30
# node created with id 267
# node created at [62, 63, 1]
# move 1
# 61 63 0
# node created with id 268
# node created at [61, 63, 0]
# move 2
# 62 62 90
# node created with id 269
# node created at [62, 62, 3]
# move 3
# 62 62 120
# node created with id 270
# node created at [62, 62, 4]
# move 4
# inside while
# closed list updated
# all list length is 270
# popped
# 62 64 30
# node created with id 271
# node created at [62, 64, 1]
# move 0
# 62 64 0
# node created with id 272
# node created at [62, 64, 0]
# move 1
# 62 64 330
# node created with id 273
# node created at [62, 64, 11]
# move 2
# 63 64 60
# node created with id 274
# node created at [63, 64, 2]
# move 3
# 63 63 90
# node created with id 275
# node created at [63, 63, 3]
# move 4
# inside while
# closed list updated
# all list length is 275
# popped
# 64 64 60
# node created with id 276
# node created at [64, 64, 2]
# move 0
# 64 65 30
# node created with id 277
# node created at [64, 65, 1]
# move 1
# 63 65 0
# node created with id 278
# node created at [63, 65, 0]
# move 2
# 64 64 90
# node created with id 279
# node created at [64, 64, 3]
# move 3
# 64 64 120
# node created with id 280
# node created at [64, 64, 4]
# move 4
# inside while
# closed list updated
# all list length is 280
# popped
# 64 66 30
# node created with id 281
# node created at [64, 66, 1]
# move 0
# 64 66 0
# node created with id 282
# node created at [64, 66, 0]
# move 1
# 64 66 330
# node created with id 283
# node created at [64, 66, 11]
# move 2
# 65 66 60
# node created with id 284
# node created at [65, 66, 2]
# move 3
# 65 65 90
# node created with id 285
# node created at [65, 65, 3]
# move 4
# inside while
# closed list updated
# all list length is 285
# popped
# 66 66 60
# node created with id 286
# node created at [66, 66, 2]
# move 0
# 66 67 30
# node created with id 287
# node created at [66, 67, 1]
# move 1
# 65 67 0
# node created with id 288
# node created at [65, 67, 0]
# move 2
# 66 66 90
# node created with id 289
# node created at [66, 66, 3]
# move 3
# 66 66 120
# node created with id 290
# node created at [66, 66, 4]
# move 4
# inside while
# closed list updated
# all list length is 290
# popped
# 66 68 30
# node created with id 291
# node created at [66, 68, 1]
# move 0
# 66 68 0
# node created with id 292
# node created at [66, 68, 0]
# move 1
# 66 68 330
# node created with id 293
# node created at [66, 68, 11]
# move 2
# 67 68 60
# node created with id 294
# node created at [67, 68, 2]
# move 3
# 67 67 90
# node created with id 295
# node created at [67, 67, 3]
# move 4
# inside while
# closed list updated
# all list length is 295
# popped
# 68 68 60
# node created with id 296
# node created at [68, 68, 2]
# move 0
# 68 69 30
# node created with id 297
# node created at [68, 69, 1]
# move 1
# 67 69 0
# node created with id 298
# node created at [67, 69, 0]
# move 2
# 68 68 90
# node created with id 299
# node created at [68, 68, 3]
# move 3
# 68 68 120
# node created with id 300
# node created at [68, 68, 4]
# move 4
# inside while
# closed list updated
# all list length is 300
# popped
# 68 70 30
# node created with id 301
# node created at [68, 70, 1]
# move 0
# 68 70 0
# node created with id 302
# node created at [68, 70, 0]
# move 1
# 68 70 330
# node created with id 303
# node created at [68, 70, 11]
# move 2
# 69 70 60
# node created with id 304
# node created at [69, 70, 2]
# move 3
# 69 69 90
# node created with id 305
# node created at [69, 69, 3]
# move 4
# inside while
# closed list updated
# all list length is 305
# popped
# 70 70 60
# node created with id 306
# node created at [70, 70, 2]
# move 0
# 70 71 30
# node created with id 307
# node created at [70, 71, 1]
# move 1
# 69 71 0
# node created with id 308
# node created at [69, 71, 0]
# move 2
# 70 70 90
# node created with id 309
# node created at [70, 70, 3]
# move 3
# 70 70 120
# node created with id 310
# node created at [70, 70, 4]
# move 4
# inside while
# closed list updated
# all list length is 310
# popped
# 70 72 30
# node created with id 311
# node created at [70, 72, 1]
# move 0
# 70 72 0
# node created with id 312
# node created at [70, 72, 0]
# move 1
# 70 72 330
# node created with id 313
# node created at [70, 72, 11]
# move 2
# 71 72 60
# node created with id 314
# node created at [71, 72, 2]
# move 3
# 71 71 90
# node created with id 315
# node created at [71, 71, 3]
# move 4
# inside while
# closed list updated
# all list length is 315
# popped
# 72 72 60
# node created with id 316
# node created at [72, 72, 2]
# move 0
# 72 73 30
# node created with id 317
# node created at [72, 73, 1]
# move 1
# 71 73 0
# node created with id 318
# node created at [71, 73, 0]
# move 2
# 72 72 90
# node created with id 319
# node created at [72, 72, 3]
# move 3
# 72 72 120
# node created with id 320
# node created at [72, 72, 4]
# move 4
# inside while
# closed list updated
# all list length is 320
# popped
# 72 74 30
# node created with id 321
# node created at [72, 74, 1]
# move 0
# 72 74 0
# node created with id 322
# node created at [72, 74, 0]
# move 1
# 72 74 330
# node created with id 323
# node created at [72, 74, 11]
# move 2
# 73 74 60
# node created with id 324
# node created at [73, 74, 2]
# move 3
# 73 73 90
# node created with id 325
# node created at [73, 73, 3]
# move 4
# inside while
# closed list updated
# all list length is 325
# popped
# 74 74 60
# node created with id 326
# node created at [74, 74, 2]
# move 0
# 74 75 30
# node created with id 327
# node created at [74, 75, 1]
# move 1
# 73 75 0
# node created with id 328
# node created at [73, 75, 0]
# move 2
# 74 74 90
# node created with id 329
# node created at [74, 74, 3]
# move 3
# 74 74 120
# node created with id 330
# node created at [74, 74, 4]
# move 4
# inside while
# closed list updated
# all list length is 330
# popped
# 74 76 30
# node created with id 331
# node created at [74, 76, 1]
# move 0
# 74 76 0
# node created with id 332
# node created at [74, 76, 0]
# move 1
# 74 76 330
# node created with id 333
# node created at [74, 76, 11]
# move 2
# 75 76 60
# node created with id 334
# node created at [75, 76, 2]
# move 3
# 75 75 90
# node created with id 335
# node created at [75, 75, 3]
# move 4
# inside while
# closed list updated
# all list length is 335
# popped
# 76 76 60
# node created with id 336
# node created at [76, 76, 2]
# move 0
# 76 77 30
# node created with id 337
# node created at [76, 77, 1]
# move 1
# 75 77 0
# node created with id 338
# node created at [75, 77, 0]
# move 2
# 76 76 90
# node created with id 339
# node created at [76, 76, 3]
# move 3
# 76 76 120
# node created with id 340
# node created at [76, 76, 4]
# move 4
# inside while
# closed list updated
# all list length is 340
# popped
# 76 78 30
# node created with id 341
# node created at [76, 78, 1]
# move 0
# 76 78 0
# node created with id 342
# node created at [76, 78, 0]
# move 1
# 76 78 330
# node created with id 343
# node created at [76, 78, 11]
# move 2
# 77 78 60
# node created with id 344
# node created at [77, 78, 2]
# move 3
# 77 77 90
# node created with id 345
# node created at [77, 77, 3]
# move 4
# inside while
# closed list updated
# all list length is 345
# popped
# 78 78 60
# node created with id 346
# node created at [78, 78, 2]
# move 0
# 78 79 30
# node created with id 347
# node created at [78, 79, 1]
# move 1
# 77 79 0
# node created with id 348
# node created at [77, 79, 0]
# move 2
# 78 78 90
# node created with id 349
# node created at [78, 78, 3]
# move 3
# 78 78 120
# node created with id 350
# node created at [78, 78, 4]
# move 4
# inside while
# closed list updated
# all list length is 350
# popped
# 78 80 30
# node created with id 351
# node created at [78, 80, 1]
# move 0
# 78 80 0
# node created with id 352
# node created at [78, 80, 0]
# move 1
# 78 80 330
# node created with id 353
# node created at [78, 80, 11]
# move 2
# 79 80 60
# node created with id 354
# node created at [79, 80, 2]
# move 3
# 79 79 90
# node created with id 355
# node created at [79, 79, 3]
# move 4
# inside while
# closed list updated
# all list length is 355
# popped
# 80 80 60
# node created with id 356
# node created at [80, 80, 2]
# move 0
# 80 81 30
# node created with id 357
# node created at [80, 81, 1]
# move 1
# 79 81 0
# node created with id 358
# node created at [79, 81, 0]
# move 2
# 80 80 90
# node created with id 359
# node created at [80, 80, 3]
# move 3
# 80 80 120
# node created with id 360
# node created at [80, 80, 4]
# move 4
# inside while
# closed list updated
# all list length is 360
# popped
# 80 82 30
# node created with id 361
# node created at [80, 82, 1]
# move 0
# 80 82 0
# node created with id 362
# node created at [80, 82, 0]
# move 1
# 80 82 330
# node created with id 363
# node created at [80, 82, 11]
# move 2
# 81 82 60
# node created with id 364
# node created at [81, 82, 2]
# move 3
# 81 81 90
# node created with id 365
# node created at [81, 81, 3]
# move 4
# inside while
# closed list updated
# all list length is 365
# popped
# 82 82 60
# node created with id 366
# node created at [82, 82, 2]
# move 0
# 82 83 30
# node created with id 367
# node created at [82, 83, 1]
# move 1
# 81 83 0
# node created with id 368
# node created at [81, 83, 0]
# move 2
# 82 82 90
# node created with id 369
# node created at [82, 82, 3]
# move 3
# 82 82 120
# node created with id 370
# node created at [82, 82, 4]
# move 4
# inside while
# closed list updated
# all list length is 370
# popped
# 82 84 30
# node created with id 371
# node created at [82, 84, 1]
# move 0
# 82 84 0
# node created with id 372
# node created at [82, 84, 0]
# move 1
# 82 84 330
# node created with id 373
# node created at [82, 84, 11]
# move 2
# 83 84 60
# node created with id 374
# node created at [83, 84, 2]
# move 3
# 83 83 90
# node created with id 375
# node created at [83, 83, 3]
# move 4
# inside while
# closed list updated
# all list length is 375
# popped
# 84 84 60
# node created with id 376
# node created at [84, 84, 2]
# move 0
# 84 85 30
# node created with id 377
# node created at [84, 85, 1]
# move 1
# 83 85 0
# node created with id 378
# node created at [83, 85, 0]
# move 2
# 84 84 90
# node created with id 379
# node created at [84, 84, 3]
# move 3
# 84 84 120
# node created with id 380
# node created at [84, 84, 4]
# move 4
# inside while
# closed list updated
# all list length is 380
# popped
# 84 86 30
# node created with id 381
# node created at [84, 86, 1]
# move 0
# 84 86 0
# node created with id 382
# node created at [84, 86, 0]
# move 1
# 84 86 330
# node created with id 383
# node created at [84, 86, 11]
# move 2
# 85 86 60
# node created with id 384
# node created at [85, 86, 2]
# move 3
# 85 85 90
# node created with id 385
# node created at [85, 85, 3]
# move 4
# inside while
# closed list updated
# all list length is 385
# popped
# 86 86 60
# node created with id 386
# node created at [86, 86, 2]
# move 0
# 86 87 30
# node created with id 387
# node created at [86, 87, 1]
# move 1
# 85 87 0
# node created with id 388
# node created at [85, 87, 0]
# move 2
# 86 86 90
# node created with id 389
# node created at [86, 86, 3]
# move 3
# 86 86 120
# node created with id 390
# node created at [86, 86, 4]
# move 4
# inside while
# closed list updated
# all list length is 390
# popped
# 86 88 30
# node created with id 391
# node created at [86, 88, 1]
# move 0
# 86 88 0
# node created with id 392
# node created at [86, 88, 0]
# move 1
# 86 88 330
# node created with id 393
# node created at [86, 88, 11]
# move 2
# 87 88 60
# node created with id 394
# node created at [87, 88, 2]
# move 3
# 87 87 90
# node created with id 395
# node created at [87, 87, 3]
# move 4
# inside while
# closed list updated
# all list length is 395
# popped
# 88 88 60
# node created with id 396
# node created at [88, 88, 2]
# move 0
# 88 89 30
# node created with id 397
# node created at [88, 89, 1]
# move 1
# 87 89 0
# node created with id 398
# node created at [87, 89, 0]
# move 2
# 88 88 90
# node created with id 399
# node created at [88, 88, 3]
# move 3
# 88 88 120
# node created with id 400
# node created at [88, 88, 4]
# move 4
# inside while
# closed list updated
# all list length is 400
# popped
# 88 90 30
# node created with id 401
# node created at [88, 90, 1]
# move 0
# 88 90 0
# node created with id 402
# node created at [88, 90, 0]
# move 1
# 88 90 330
# node created with id 403
# node created at [88, 90, 11]
# move 2
# 89 90 60
# node created with id 404
# node created at [89, 90, 2]
# move 3
# 89 89 90
# node created with id 405
# node created at [89, 89, 3]
# move 4
# inside while
# closed list updated
# all list length is 405
# popped
# 90 90 60
# node created with id 406
# node created at [90, 90, 2]
# move 0
# 90 91 30
# node created with id 407
# node created at [90, 91, 1]
# move 1
# 89 91 0
# node created with id 408
# node created at [89, 91, 0]
# move 2
# 90 90 90
# node created with id 409
# node created at [90, 90, 3]
# move 3
# 90 90 120
# node created with id 410
# node created at [90, 90, 4]
# move 4
# inside while
# closed list updated
# all list length is 410
# popped
# 90 92 30
# node created with id 411
# node created at [90, 92, 1]
# move 0
# 90 92 0
# node created with id 412
# node created at [90, 92, 0]
# move 1
# 90 92 330
# node created with id 413
# node created at [90, 92, 11]
# move 2
# 91 92 60
# node created with id 414
# node created at [91, 92, 2]
# move 3
# 91 91 90
# node created with id 415
# node created at [91, 91, 3]
# move 4
# inside while
# closed list updated
# all list length is 415
# popped
# 92 92 60
# node created with id 416
# node created at [92, 92, 2]
# move 0
# 92 93 30
# node created with id 417
# node created at [92, 93, 1]
# move 1
# 91 93 0
# node created with id 418
# node created at [91, 93, 0]
# move 2
# 92 92 90
# node created with id 419
# node created at [92, 92, 3]
# move 3
# 92 92 120
# node created with id 420
# node created at [92, 92, 4]
# move 4
# inside while
# closed list updated
# all list length is 420
# popped
# 92 94 30
# node created with id 421
# node created at [92, 94, 1]
# move 0
# 92 94 0
# node created with id 422
# node created at [92, 94, 0]
# move 1
# 92 94 330
# node created with id 423
# node created at [92, 94, 11]
# move 2
# 93 94 60
# node created with id 424
# node created at [93, 94, 2]
# move 3
# 93 93 90
# node created with id 425
# node created at [93, 93, 3]
# move 4
# inside while
# closed list updated
# all list length is 425
# popped
# 94 94 60
# node created with id 426
# node created at [94, 94, 2]
# move 0
# 94 95 30
# node created with id 427
# node created at [94, 95, 1]
# move 1
# 93 95 0
# node created with id 428
# node created at [93, 95, 0]
# move 2
# 94 94 90
# node created with id 429
# node created at [94, 94, 3]
# move 3
# 94 94 120
# node created with id 430
# node created at [94, 94, 4]
# move 4
# inside while
# closed list updated
# all list length is 430
# popped
# 94 96 30
# node created with id 431
# node created at [94, 96, 1]
# move 0
# 94 96 0
# node created with id 432
# node created at [94, 96, 0]
# move 1
# 94 96 330
# node created with id 433
# node created at [94, 96, 11]
# move 2
# 95 96 60
# node created with id 434
# node created at [95, 96, 2]
# move 3
# 95 95 90
# node created with id 435
# node created at [95, 95, 3]
# move 4
# inside while
# closed list updated
# all list length is 435
# popped
# 96 96 60
# node created with id 436
# node created at [96, 96, 2]
# move 0
# 96 97 30
# node created with id 437
# node created at [96, 97, 1]
# move 1
# 95 97 0
# node created with id 438
# node created at [95, 97, 0]
# move 2
# 96 96 90
# node created with id 439
# node created at [96, 96, 3]
# move 3
# 96 96 120
# node created with id 440
# node created at [96, 96, 4]
# move 4
# inside while
# closed list updated
# all list length is 440
# popped
# 96 98 30
# node created with id 441
# node created at [96, 98, 1]
# move 0
# 96 98 0
# node created with id 442
# node created at [96, 98, 0]
# move 1
# 96 98 330
# node created with id 443
# node created at [96, 98, 11]
# move 2
# 97 98 60
# node created with id 444
# node created at [97, 98, 2]
# move 3
# 97 97 90
# node created with id 445
# node created at [97, 97, 3]
# move 4
# inside while
# closed list updated
# all list length is 445
# popped
# 98 98 60
# node created with id 446
# node created at [98, 98, 2]
# move 0
# 98 99 30
# node created with id 447
# node created at [98, 99, 1]
# move 1
# 97 99 0
# node created with id 448
# node created at [97, 99, 0]
# move 2
# 98 98 90
# node created with id 449
# node created at [98, 98, 3]
# move 3
# 98 98 120
# node created with id 450
# node created at [98, 98, 4]
# move 4
# inside while
# closed list updated
# all list length is 450
# popped
# 98 100 30
# node created with id 451
# node created at [98, 100, 1]
# move 0
# 98 100 0
# node created with id 452
# node created at [98, 100, 0]
# move 1
# 98 100 330
# node created with id 453
# node created at [98, 100, 11]
# move 2
# 99 100 60
# node created with id 454
# node created at [99, 100, 2]
# move 3
# 99 99 90
# node created with id 455
# node created at [99, 99, 3]
# move 4
# inside while
# closed list updated
# all list length is 455
# popped
# 100 100 60
# node created with id 456
# node created at [100, 100, 2]
# move 0
# 100 101 30
# node created with id 457
# node created at [100, 101, 1]
# move 1
# 99 101 0
# node created with id 458
# node created at [99, 101, 0]
# move 2
# 100 100 90
# node created with id 459
# node created at [100, 100, 3]
# move 3
# 100 100 120
# node created with id 460
# node created at [100, 100, 4]
# move 4
# inside while
# closed list updated
# all list length is 460
# popped
# 100 102 30
# node created with id 461
# node created at [100, 102, 1]
# move 0
# 100 102 0
# node created with id 462
# node created at [100, 102, 0]
# move 1
# 100 102 330
# node created with id 463
# node created at [100, 102, 11]
# move 2
# 101 102 60
# node created with id 464
# node created at [101, 102, 2]
# move 3
# 101 101 90
# node created with id 465
# node created at [101, 101, 3]
# move 4
# inside while
# closed list updated
# all list length is 465
# popped
# 100 103 30
# node created with id 466
# node created at [100, 103, 1]
# move 0
# 100 103 0
# node created with id 467
# node created at [100, 103, 0]
# move 1
# 100 103 330
# node created with id 468
# node created at [100, 103, 11]
# move 2
# 101 102 60
# Node exists, checking cost...
# move 3
# 101 102 90
# node created with id 469
# node created at [101, 102, 3]
# move 4
# inside while
# closed list updated
# all list length is 469
# popped
# 100 103 0
# Node exists, checking cost...
# move 0
# 100 103 330
# Node exists, checking cost...
# move 1
# 99 102 300
# node created with id 470
# node created at [99, 102, 10]
# move 2
# 100 103 30
# Node exists, checking cost...
# move 3
# 101 102 60
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 470
# popped
# 100 103 330
# Node exists, checking cost...
# move 0
# 99 102 300
# Node exists, checking cost...
# move 1
# 99 102 270
# node created with id 471
# node created at [99, 102, 9]
# move 2
# 100 103 0
# Node exists, checking cost...
# move 3
# 100 103 30
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 471
# popped
# 100 104 30
# node created with id 472
# node created at [100, 104, 1]
# move 0
# 100 104 0
# node created with id 473
# node created at [100, 104, 0]
# move 1
# 100 104 330
# node created with id 474
# node created at [100, 104, 11]
# move 2
# 101 104 60
# node created with id 475
# node created at [101, 104, 2]
# move 3
# 101 103 90
# node created with id 476
# node created at [101, 103, 3]
# move 4
# inside while
# closed list updated
# all list length is 476
# popped
# 100 104 0
# Node exists, checking cost...
# move 0
# 100 104 330
# Node exists, checking cost...
# move 1
# 99 104 300
# node created with id 477
# node created at [99, 104, 10]
# move 2
# 100 104 30
# Node exists, checking cost...
# move 3
# 101 104 60
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 477
# popped
# 100 104 330
# Node exists, checking cost...
# move 0
# 99 104 300
# Node exists, checking cost...
# move 1
# 99 103 270
# node created with id 478
# node created at [99, 103, 9]
# move 2
# 100 104 0
# Node exists, checking cost...
# move 3
# 100 104 30
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 478
# popped
# 100 105 30
# node created with id 479
# node created at [100, 105, 1]
# move 0
# 100 105 0
# node created with id 480
# node created at [100, 105, 0]
# move 1
# 100 105 330
# node created with id 481
# node created at [100, 105, 11]
# move 2
# 101 104 60
# Node exists, checking cost...
# move 3
# 101 104 90
# node created with id 482
# node created at [101, 104, 3]
# move 4
# inside while
# closed list updated
# all list length is 482
# popped
# 100 105 0
# Node exists, checking cost...
# move 0
# 100 105 330
# Node exists, checking cost...
# move 1
# 99 104 300
# Node exists, checking cost...
# move 2
# 100 105 30
# Node exists, checking cost...
# move 3
# 101 104 60
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 482
# popped
# 100 105 330
# Node exists, checking cost...
# move 0
# 99 104 300
# Node exists, checking cost...
# move 1
# 99 104 270
# node created with id 483
# node created at [99, 104, 9]
# move 2
# 100 105 0
# Node exists, checking cost...
# move 3
# 100 105 30
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 483
# popped
# 100 106 30
# node created with id 484
# node created at [100, 106, 1]
# move 0
# 100 106 0
# node created with id 485
# node created at [100, 106, 0]
# move 1
# 100 106 330
# node created with id 486
# node created at [100, 106, 11]
# move 2
# 101 106 60
# node created with id 487
# node created at [101, 106, 2]
# move 3
# 101 105 90
# node created with id 488
# node created at [101, 105, 3]
# move 4
# inside while
# closed list updated
# all list length is 488
# popped
# 100 106 0
# Node exists, checking cost...
# move 0
# 100 106 330
# Node exists, checking cost...
# move 1
# 99 106 300
# node created with id 489
# node created at [99, 106, 10]
# move 2
# 100 106 30
# Node exists, checking cost...
# move 3
# 101 106 60
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 489
# popped
# 100 106 330
# Node exists, checking cost...
# move 0
# 99 106 300
# Node exists, checking cost...
# move 1
# 99 105 270
# node created with id 490
# node created at [99, 105, 9]
# move 2
# 100 106 0
# Node exists, checking cost...
# move 3
# 100 106 30
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 490
# popped
# 100 107 30
# node created with id 491
# node created at [100, 107, 1]
# move 0
# 100 107 0
# node created with id 492
# node created at [100, 107, 0]
# move 1
# 100 107 330
# node created with id 493
# node created at [100, 107, 11]
# move 2
# 101 106 60
# Node exists, checking cost...
# move 3
# 101 106 90
# node created with id 494
# node created at [101, 106, 3]
# move 4
# inside while
# closed list updated
# all list length is 494
# popped
# 100 107 0
# Node exists, checking cost...
# move 0
# 100 107 330
# Node exists, checking cost...
# move 1
# 99 106 300
# Node exists, checking cost...
# move 2
# 100 107 30
# Node exists, checking cost...
# move 3
# 101 106 60
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 494
# popped
# 100 107 330
# Node exists, checking cost...
# move 0
# 99 106 300
# Node exists, checking cost...
# move 1
# 99 106 270
# node created with id 495
# node created at [99, 106, 9]
# move 2
# 100 107 0
# Node exists, checking cost...
# move 3
# 100 107 30
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 495
# popped
# 100 108 30
# node created with id 496
# node created at [100, 108, 1]
# move 0
# 100 108 0
# node created with id 497
# node created at [100, 108, 0]
# move 1
# 100 108 330
# node created with id 498
# node created at [100, 108, 11]
# move 2
# 101 108 60
# node created with id 499
# node created at [101, 108, 2]
# move 3
# 101 107 90
# node created with id 500
# node created at [101, 107, 3]
# move 4
# inside while
# closed list updated
# all list length is 500
# popped
# 100 108 0
# Node exists, checking cost...
# move 0
# 100 108 330
# Node exists, checking cost...
# move 1
# 99 108 300
# node created with id 501
# node created at [99, 108, 10]
# move 2
# 100 108 30
# Node exists, checking cost...
# move 3
# 101 108 60
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 501
# popped
# 100 108 330
# Node exists, checking cost...
# move 0
# 99 108 300
# Node exists, checking cost...
# move 1
# 99 107 270
# node created with id 502
# node created at [99, 107, 9]
# move 2
# 100 108 0
# Node exists, checking cost...
# move 3
# 100 108 30
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 502
# popped
# 100 109 30
# node created with id 503
# node created at [100, 109, 1]
# move 0
# 100 109 0
# node created with id 504
# node created at [100, 109, 0]
# move 1
# 100 109 330
# node created with id 505
# node created at [100, 109, 11]
# move 2
# 101 108 60
# Node exists, checking cost...
# move 3
# 101 108 90
# node created with id 506
# node created at [101, 108, 3]
# move 4
# inside while
# closed list updated
# all list length is 506
# popped
# 100 109 0
# Node exists, checking cost...
# move 0
# 100 109 330
# Node exists, checking cost...
# move 1
# 99 108 300
# Node exists, checking cost...
# move 2
# 100 109 30
# Node exists, checking cost...
# move 3
# 101 108 60
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 506
# popped
# 100 109 330
# Node exists, checking cost...
# move 0
# 99 108 300
# Node exists, checking cost...
# move 1
# 99 108 270
# node created with id 507
# node created at [99, 108, 9]
# move 2
# 100 109 0
# Node exists, checking cost...
# move 3
# 100 109 30
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 507
# popped
# 100 110 30
# node created with id 508
# node created at [100, 110, 1]
# move 0
# 100 110 0
# node created with id 509
# node created at [100, 110, 0]
# move 1
# 100 110 330
# node created with id 510
# node created at [100, 110, 11]
# move 2
# 101 110 60
# node created with id 511
# node created at [101, 110, 2]
# move 3
# 101 109 90
# node created with id 512
# node created at [101, 109, 3]
# move 4
# inside while
# closed list updated
# all list length is 512
# popped
# 100 110 0
# Node exists, checking cost...
# move 0
# 100 110 330
# Node exists, checking cost...
# move 1
# 99 110 300
# node created with id 513
# node created at [99, 110, 10]
# move 2
# 100 110 30
# Node exists, checking cost...
# move 3
# 101 110 60
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 513
# popped
# 100 110 330
# Node exists, checking cost...
# move 0
# 99 110 300
# Node exists, checking cost...
# move 1
# 99 109 270
# node created with id 514
# node created at [99, 109, 9]
# move 2
# 100 110 0
# Node exists, checking cost...
# move 3
# 100 110 30
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 514
# popped
# 100 111 30
# node created with id 515
# node created at [100, 111, 1]
# move 0
# 100 111 0
# node created with id 516
# node created at [100, 111, 0]
# move 1
# 100 111 330
# node created with id 517
# node created at [100, 111, 11]
# move 2
# 101 110 60
# Node exists, checking cost...
# move 3
# 101 110 90
# node created with id 518
# node created at [101, 110, 3]
# move 4
# inside while
# closed list updated
# all list length is 518
# popped
# 100 111 0
# Node exists, checking cost...
# move 0
# 100 111 330
# Node exists, checking cost...
# move 1
# 99 110 300
# Node exists, checking cost...
# move 2
# 100 111 30
# Node exists, checking cost...
# move 3
# 101 110 60
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 518
# popped
# 100 111 330
# Node exists, checking cost...
# move 0
# 99 110 300
# Node exists, checking cost...
# move 1
# 99 110 270
# node created with id 519
# node created at [99, 110, 9]
# move 2
# 100 111 0
# Node exists, checking cost...
# move 3
# 100 111 30
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 519
# popped
# 100 112 30
# node created with id 520
# node created at [100, 112, 1]
# move 0
# 100 112 0
# node created with id 521
# node created at [100, 112, 0]
# move 1
# 100 112 330
# node created with id 522
# node created at [100, 112, 11]
# move 2
# 101 112 60
# node created with id 523
# node created at [101, 112, 2]
# ...
# move 0
# 96 106 330
# node created with id 1354
# node created at [96, 106, 11]
# move 1
# 96 106 300
# Node exists, checking cost...
# move 2
# 98 106 30
# Node exists, checking cost...
# move 3
# 98 106 60
# node created with id 1355
# node created at [98, 106, 2]
# move 4
# inside while
# closed list updated
# all list length is 1355
# popped
# 99 106 60
# Node exists, checking cost...
# move 0
# 98 107 30
# Node exists, checking cost...
# move 1
# 98 107 0
# Node exists, checking cost...
# move 2
# 99 106 90
# Node exists, checking cost...
# move 3
# 99 106 120
# node created with id 1356
# node created at [99, 106, 4]
# move 4
# inside while
# closed list updated
# all list length is 1356
# popped
# 103 107 0
# Node exists, checking cost...
# move 0
# 102 107 330
# Node exists, checking cost...
# move 1
# 102 106 300
# Node exists, checking cost...
# move 2
# 104 107 30
# Node exists, checking cost...
# move 3
# 104 106 60
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 1356
# popped
# 97 107 0
# Node exists, checking cost...
# move 0
# 96 107 330
# Node exists, checking cost...
# move 1
# 96 106 300
# Node exists, checking cost...
# move 2
# 98 107 30
# Node exists, checking cost...
# move 3
# 98 106 60
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 1356
# popped
# 102 127 30
# Node exists, checking cost...
# move 0
# 102 127 0
# node created with id 1357
# node created at [102, 127, 0]
# move 1
# 102 127 330
# node created with id 1358
# node created at [102, 127, 11]
# move 2
# 103 126 60
# Node exists, checking cost...
# move 3
# 103 126 90
# node created with id 1359
# node created at [103, 126, 3]
# move 4
# inside while
# closed list updated
# all list length is 1359
# popped
# 103 126 60
# Node exists, checking cost...
# move 0
# 102 127 30
# Node exists, checking cost...
# move 1
# 102 127 0
# Node exists, checking cost...
# move 2
# 103 126 90
# Node exists, checking cost...
# move 3
# 103 126 120
# node created with id 1360
# node created at [103, 126, 4]
# move 4
# inside while
# closed list updated
# all list length is 1360
# popped
# 98 127 330
# Node exists, checking cost...
# move 0
# 97 126 300
# Node exists, checking cost...
# move 1
# 97 126 270
# node created with id 1361
# node created at [97, 126, 9]
# move 2
# 98 127 0
# node created with id 1362
# node created at [98, 127, 0]
# move 3
# 98 127 30
# node created with id 1363
# node created at [98, 127, 1]
# move 4
# inside while
# closed list updated
# all list length is 1363
# popped
# 97 126 300
# Node exists, checking cost...
# move 0
# 97 126 270
# Node exists, checking cost...
# move 1
# 97 126 240
# node created with id 1364
# node created at [97, 126, 8]
# move 2
# 98 127 330
# Node exists, checking cost...
# move 3
# 98 127 0
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 1364
# popped
# 104 108 60
# node created with id 1365
# node created at [104, 108, 2]
# move 0
# 104 109 30
# node created with id 1366
# node created at [104, 109, 1]
# move 1
# 103 109 0
# node created with id 1367
# node created at [103, 109, 0]
# move 2
# 104 108 90
# node created with id 1368
# node created at [104, 108, 3]
# move 3
# 104 108 120
# node created with id 1369
# node created at [104, 108, 4]
# move 4
# inside while
# closed list updated
# all list length is 1369
# popped
# 96 108 300
# node created with id 1370
# node created at [96, 108, 10]
# move 0
# 96 108 270
# node created with id 1371
# node created at [96, 108, 9]
# move 1
# 96 108 240
# node created with id 1372
# node created at [96, 108, 8]
# move 2
# 96 109 330
# node created with id 1373
# node created at [96, 109, 11]
# move 3
# 97 109 0
# node created with id 1374
# node created at [97, 109, 0]
# move 4
# inside while
# closed list updated
# all list length is 1374
# popped
# 102 127 0
# Node exists, checking cost...
# move 0
# 102 127 330
# Node exists, checking cost...
# move 1
# 101 126 300
# Node exists, checking cost...
# move 2
# 102 127 30
# Node exists, checking cost...
# move 3
# 103 126 60
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 1374
# popped
# 102 127 330
# Node exists, checking cost...
# move 0
# 101 126 300
# Node exists, checking cost...
# move 1
# 101 126 270
# node created with id 1375
# node created at [101, 126, 9]
# move 2
# 102 127 0
# Node exists, checking cost...
# move 3
# 102 127 30
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 1375
# popped
# 98 127 0
# Node exists, checking cost...
# move 0
# 98 127 330
# Node exists, checking cost...
# move 1
# 97 126 300
# Node exists, checking cost...
# move 2
# 98 127 30
# Node exists, checking cost...
# move 3
# 99 126 60
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 1375
# popped
# 98 127 30
# Node exists, checking cost...
# move 0
# 98 127 0
# Node exists, checking cost...
# move 1
# 98 127 330
# Node exists, checking cost...
# move 2
# 99 126 60
# Node exists, checking cost...
# move 3
# 99 126 90
# node created with id 1376
# node created at [99, 126, 3]
# move 4
# inside while
# closed list updated
# all list length is 1376
# popped
# 103 108 0
# node created with id 1377
# node created at [103, 108, 0]
# move 0
# 102 108 330
# Node exists, checking cost...
# move 1
# 102 108 300
# node created with id 1378
# node created at [102, 108, 10]
# move 2
# 104 108 30
# node created with id 1379
# node created at [104, 108, 1]
# move 3
# 104 108 60
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 1379
# popped
# 101 108 300
# Node exists, checking cost...
# move 0
# 101 108 270
# Node exists, checking cost...
# move 1
# 101 108 240
# node created with id 1380
# node created at [101, 108, 8]
# move 2
# 102 109 330
# Node exists, checking cost...
# move 3
# 102 109 0
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 1380
# popped
# 97 108 0
# node created with id 1381
# node created at [97, 108, 0]
# move 0
# 96 108 330
# node created with id 1382
# node created at [96, 108, 11]
# move 1
# 96 108 300
# Node exists, checking cost...
# move 2
# 98 108 30
# Node exists, checking cost...
# move 3
# 98 108 60
# node created with id 1383
# node created at [98, 108, 2]
# move 4
# inside while
# closed list updated
# all list length is 1383
# popped
# 99 108 60
# Node exists, checking cost...
# move 0
# 98 109 30
# Node exists, checking cost...
# move 1
# 98 109 0
# Node exists, checking cost...
# move 2
# 99 108 90
# Node exists, checking cost...
# move 3
# 99 108 120
# node created with id 1384
# node created at [99, 108, 4]
# move 4
# inside while
# closed list updated
# all list length is 1384
# popped
# 103 110 0
# node created with id 1385
# node created at [103, 110, 0]
# move 0
# 102 110 330
# Node exists, checking cost...
# move 1
# 102 110 300
# node created with id 1386
# node created at [102, 110, 10]
# move 2
# 104 110 30
# node created with id 1387
# node created at [104, 110, 1]
# move 3
# 104 110 60
# node created with id 1388
# node created at [104, 110, 2]
# move 4
# inside while
# closed list updated
# all list length is 1388
# popped
# 101 110 300
# Node exists, checking cost...
# move 0
# 101 110 270
# Node exists, checking cost...
# move 1
# 101 110 240
# node created with id 1389
# node created at [101, 110, 8]
# move 2
# 102 111 330
# Node exists, checking cost...
# move 3
# 102 111 0
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 1389
# popped
# 97 110 0
# node created with id 1390
# node created at [97, 110, 0]
# move 0
# 96 110 330
# node created with id 1391
# node created at [96, 110, 11]
# move 1
# 96 110 300
# node created with id 1392
# node created at [96, 110, 10]
# move 2
# 98 110 30
# Node exists, checking cost...
# move 3
# 98 110 60
# node created with id 1393
# node created at [98, 110, 2]
# move 4
# inside while
# closed list updated
# all list length is 1393
# popped
# 99 110 60
# Node exists, checking cost...
# move 0
# 98 111 30
# Node exists, checking cost...
# move 1
# 98 111 0
# Node exists, checking cost...
# move 2
# 99 110 90
# Node exists, checking cost...
# move 3
# 99 110 120
# node created with id 1394
# node created at [99, 110, 4]
# move 4
# inside while
# closed list updated
# all list length is 1394
# popped
# 103 109 0
# Node exists, checking cost...
# move 0
# 102 109 330
# Node exists, checking cost...
# move 1
# 102 108 300
# Node exists, checking cost...
# move 2
# 104 109 30
# Node exists, checking cost...
# move 3
# 104 108 60
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 1394
# popped
# 97 109 0
# Node exists, checking cost...
# move 0
# 96 109 330
# Node exists, checking cost...
# move 1
# 96 108 300
# Node exists, checking cost...
# move 2
# 98 109 30
# Node exists, checking cost...
# move 3
# 98 108 60
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 1394
# popped
# 102 128 30
# Node exists, checking cost...
# move 0
# 102 128 0
# node created with id 1395
# node created at [102, 128, 0]
# move 1
# 102 128 330
# node created with id 1396
# node created at [102, 128, 11]
# move 2
# 103 128 60
# node created with id 1397
# node created at [103, 128, 2]
# move 3
# 103 127 90
# node created with id 1398
# node created at [103, 127, 3]
# move 4
# inside while
# closed list updated
# all list length is 1398
# popped
# 98 128 330
# Node exists, checking cost...
# move 0
# 97 128 300
# node created with id 1399
# node created at [97, 128, 10]
# move 1
# 97 127 270
# node created with id 1400
# node created at [97, 127, 9]
# move 2
# 98 128 0
# node created with id 1401
# node created at [98, 128, 0]
# move 3
# 98 128 30
# node created with id 1402
# node created at [98, 128, 1]
# move 4
# inside while
# closed list updated
# all list length is 1402
# popped
# 104 110 60
# Node exists, checking cost...
# move 0
# 104 111 30
# node created with id 1403
# node created at [104, 111, 1]
# move 1
# 103 111 0
# node created with id 1404
# node created at [103, 111, 0]
# move 2
# 104 110 90
# node created with id 1405
# node created at [104, 110, 3]
# move 3
# 104 110 120
# node created with id 1406
# node created at [104, 110, 4]
# move 4
# inside while
# closed list updated
# all list length is 1406
# popped
# 96 110 300
# Node exists, checking cost...
# move 0
# 96 110 270
# node created with id 1407
# node created at [96, 110, 9]
# move 1
# 96 110 240
# node created with id 1408
# node created at [96, 110, 8]
# move 2
# 96 111 330
# node created with id 1409
# node created at [96, 111, 11]
# move 3
# 97 111 0
# node created with id 1410
# node created at [97, 111, 0]
# move 4
# inside while
# closed list updated
# all list length is 1410
# popped
# 102 128 0
# Node exists, checking cost...
# move 0
# 102 128 330
# Node exists, checking cost...
# move 1
# 101 128 300
# node created with id 1411
# node created at [101, 128, 10]
# move 2
# 102 128 30
# Node exists, checking cost...
# move 3
# 103 128 60
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 1411
# popped
# 100 128 300
# Node exists, checking cost...
# move 0
# 100 128 270
# node created with id 1412
# node created at [100, 128, 9]
# move 1
# 100 128 240
# node created with id 1413
# node created at [100, 128, 8]
# move 2
# 100 129 330
# Node exists, checking cost...
# move 3
# 101 129 0
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 1413
# popped
# 102 128 330
# Node exists, checking cost...
# move 0
# 101 128 300
# Node exists, checking cost...
# move 1
# 101 127 270
# node created with id 1414
# node created at [101, 127, 9]
# move 2
# 102 128 0
# Node exists, checking cost...
# move 3
# 102 128 30
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 1414
# popped
# 98 128 0
# Node exists, checking cost...
# move 0
# 98 128 330
# Node exists, checking cost...
# move 1
# 97 128 300
# Node exists, checking cost...
# move 2
# 98 128 30
# Node exists, checking cost...
# move 3
# 99 128 60
# node created with id 1415
# node created at [99, 128, 2]
# move 4
# inside while
# closed list updated
# all list length is 1415
# popped
# 100 128 60
# Node exists, checking cost...
# move 0
# 100 129 30
# Node exists, checking cost...
# move 1
# 99 129 0
# Node exists, checking cost...
# move 2
# 100 128 90
# node created with id 1416
# node created at [100, 128, 3]
# move 3
# 100 128 120
# node created with id 1417
# node created at [100, 128, 4]
# move 4
# inside while
# closed list updated
# all list length is 1417
# popped
# 98 128 30
# Node exists, checking cost...
# move 0
# 98 128 0
# Node exists, checking cost...
# move 1
# 98 128 330
# Node exists, checking cost...
# move 2
# 99 128 60
# Node exists, checking cost...
# move 3
# 99 127 90
# node created with id 1418
# node created at [99, 127, 3]
# move 4
# inside while
# closed list updated
# all list length is 1418
# popped
# 103 111 0
# Node exists, checking cost...
# move 0
# 102 111 330
# Node exists, checking cost...
# move 1
# 102 110 300
# Node exists, checking cost...
# move 2
# 104 111 30
# Node exists, checking cost...
# move 3
# 104 110 60
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 1418
# popped
# 97 111 0
# Node exists, checking cost...
# move 0
# 96 111 330
# Node exists, checking cost...
# move 1
# 96 110 300
# Node exists, checking cost...
# move 2
# 98 111 30
# Node exists, checking cost...
# move 3
# 98 110 60
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 1418
# popped
# 103 112 0
# node created with id 1419
# node created at [103, 112, 0]
# move 0
# 102 112 330
# Node exists, checking cost...
# move 1
# 102 112 300
# node created with id 1420
# node created at [102, 112, 10]
# move 2
# 104 112 30
# node created with id 1421
# node created at [104, 112, 1]
# move 3
# 104 112 60
# node created with id 1422
# node created at [104, 112, 2]
# move 4
# inside while
# closed list updated
# all list length is 1422
# popped
# 101 112 300
# Node exists, checking cost...
# move 0
# 101 112 270
# Node exists, checking cost...
# move 1
# 101 112 240
# node created with id 1423
# node created at [101, 112, 8]
# move 2
# 102 113 330
# Node exists, checking cost...
# move 3
# 102 113 0
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 1423
# popped
# 97 112 0
# node created with id 1424
# node created at [97, 112, 0]
# move 0
# 96 112 330
# node created with id 1425
# node created at [96, 112, 11]
# move 1
# 96 112 300
# node created with id 1426
# node created at [96, 112, 10]
# move 2
# 98 112 30
# Node exists, checking cost...
# move 3
# 98 112 60
# node created with id 1427
# node created at [98, 112, 2]
# move 4
# inside while
# closed list updated
# all list length is 1427
# popped
# 99 112 60
# Node exists, checking cost...
# move 0
# 98 113 30
# Node exists, checking cost...
# move 1
# 98 113 0
# Node exists, checking cost...
# move 2
# 99 112 90
# Node exists, checking cost...
# move 3
# 99 112 120
# node created with id 1428
# node created at [99, 112, 4]
# move 4
# inside while
# closed list updated
# all list length is 1428
# popped
# 104 112 60
# Node exists, checking cost...
# move 0
# 104 113 30
# node created with id 1429
# node created at [104, 113, 1]
# move 1
# 103 113 0
# node created with id 1430
# node created at [103, 113, 0]
# move 2
# 104 112 90
# node created with id 1431
# node created at [104, 112, 3]
# move 3
# 104 112 120
# node created with id 1432
# node created at [104, 112, 4]
# move 4
# inside while
# closed list updated
# all list length is 1432
# popped
# 96 112 300
# Node exists, checking cost...
# move 0
# 96 112 270
# node created with id 1433
# node created at [96, 112, 9]
# move 1
# 96 112 240
# node created with id 1434
# node created at [96, 112, 8]
# move 2
# 96 113 330
# node created with id 1435
# node created at [96, 113, 11]
# move 3
# 97 113 0
# node created with id 1436
# node created at [97, 113, 0]
# move 4
# inside while
# closed list updated
# all list length is 1436
# popped
# 101 138 0
# node created with id 1437
# node created at [101, 138, 0]
# move 0
# 100 138 330
# Node exists, checking cost...
# move 1
# 100 138 300
# node created with id 1438
# node created at [100, 138, 10]
# move 2
# 102 138 30
# node created with id 1439
# node created at [102, 138, 1]
# move 3
# 102 138 60
# node created with id 1440
# node created at [102, 138, 2]
# move 4
# inside while
# closed list updated
# all list length is 1440
# popped
# 99 138 300
# Node exists, checking cost...
# move 0
# 99 138 270
# Node exists, checking cost...
# move 1
# 99 138 240
# node created with id 1441
# node created at [99, 138, 8]
# move 2
# 100 139 330
# Node exists, checking cost...
# move 3
# 100 139 0
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 1441
# popped
# 99 138 0
# node created with id 1442
# node created at [99, 138, 0]
# move 0
# 98 138 330
# node created with id 1443
# node created at [98, 138, 11]
# move 1
# 98 138 300
# node created with id 1444
# node created at [98, 138, 10]
# move 2
# 100 138 30
# Node exists, checking cost...
# move 3
# 100 138 60
# node created with id 1445
# node created at [100, 138, 2]
# move 4
# inside while
# closed list updated
# this will be done at [100, 138, 2]
# all list length is 1445
# done

# %%
All_list[-1].node_loc

# %%
goal_list

# %%
Open_list.qsize()

# %%
len(All_list)

# %%
len(allp_map)

# %% [markdown]
# Backtracking

# %%
# if (map_obs4[goal_location[0], goal_location[1]]!=-1 and map_obs4[goal_location[0], goal_location[1]]!=-2 ):
#     x_a = []
#     y_a = []
#     backtrack(All_list, x_a, y_a)
#     mp.show()
#     mp.axis([0, 400, 0, 250])
#     mp.plot(y_a,x_a)
#     mp.plot(x_nc, y_nc)
#     mp.plot(x_t1_nc,y_t1_nc)
#     mp.plot(x_t2_nc,y_t2_nc)
#     mp.plot(x_h_nc,y_h_nc)
# else:
#     print('cannot be back tracked')
