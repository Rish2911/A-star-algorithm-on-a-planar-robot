# %%
# import numpy as np
# import sympy as sp
# import os
# from queue import PriorityQueue

# import matplotlib.pyplot as plt

# #node size ratio (unit/node)
# def map():
#     global x_size, y_size, map_def
   
#     x_size = int(400/Rat) #x and y  as per gloabl coordinate system and not matrix
#     y_size = int(250/Rat)
#     map_def = np.zeros((y_size,x_size,12))
#     map_def[:,:,:] = -2

# """Common obstacle code"""



# """Circle"""

# #x is column and y is row for the matrix
# def circle_obs():
#     global x_c, y_c, x_nc, y_nc, map_obs1, allp_map
#     x_c = []
#     y_c = []
#     x_nc = []
#     y_nc = []
#     y_centre = int((249 - 65)/Rat)
#     x_centre = int((399 - 100)/Rat)
#     radius_c = int(55/Rat) #radius of cicle including clearance
#     radius = int(40/Rat)
#     map_obs1 = np.copy(map_def) # a deep copy #chnage this to map_obs1
#     for x in range(int(240/Rat),int(360/Rat)):
#         for y in range(int(120/Rat), int(240/Rat)):
#             if (np.sqrt((x-x_centre)**2 + (y-y_centre)**2)) < radius_c:
#                 map_obs1[y, x,:] = -1 #obstacle space updated as -1
#                 x_c.append(x) #to be used for plotting
#                 y_c.append(y)
               
#             if (np.sqrt((x-x_centre)**2 + (y-y_centre)**2)) < radius:
#                 x_nc.append(x) #list of obstacle without clearance
#                 y_nc.append(y)
#                 allp_map.append([x,y]) #to be used for visualisation on pygame

# """Triangles"""
# def triang_obs():
#     global x_t1, y_t1, x_t1_nc, y_t1_nc, map_obs2, x_t2_nc, y_t2_nc, x_t2, y_t2, allp_map, Rat
#     x_t1 = []
#     y_t1 = []
#     x_t2 = []
#     y_t2 = []
#     x_t1_nc = []
#     y_t1_nc = []
#     x_t2_nc = []
#     y_t2_nc = []
#     map_obs2 = np.copy(map_obs1)
#     for x in range(int(170/Rat)):
#         for y in range(int(40*Rat),int(240/Rat)):
#             #with clearance
#             if (y - (6/7)*x - ((779/7) + 15)/Rat)<=0 and (y - (-85/69)*x - ((15880/69) -18)/Rat)>=0 and (y - (-16/5)*x - ((2169/5) +25)/Rat)<=0 :
#                 map_obs2[y,x,:] = -1
#                 x_t1.append(x)
#                 y_t1.append(y)
#                 # allp_map.append([x,y])
#             #without clearance
#             if (y - (6/7)*x - ((779/7))/Rat)<=0 and (y - (-85/69)*x - ((15880/69))/Rat)>=0 and (y - (-16/5)*x - ((2169/5) +10)/Rat)<=0 :
#                 map_obs2[y,x,:] = -1
#                 x_t1_nc.append(x)
#                 y_t1_nc.append(y)
#                 allp_map.append([x,y])
#                 #with clearance
#             if (y - (6/7)*x - ((779/7) - 15)/Rat)>=0 and (y - (-85/69)*x - ((15880/69) -18)/Rat)>=0 and (y - (25/79)*x - ((13661/79) +15)/Rat)<=0:
#                 map_obs2[y,x,:] = -1
#                 x_t2.append(x)
#                 y_t2.append(y)
#                 # allp_map.append([x,y])
#                 #without clearance
#             if (y - (6/7)*x - ((779/7) )/Rat)>=0 and (y - (-85/69)*x - ((15880/69))/Rat)>=0 and (y - (25/79)*x - ((13661/79))/Rat)<=0:
#                 map_obs2[y,x,:] = -1
#                 x_t2_nc.append(x)
#                 y_t2_nc.append(y)
#                 allp_map.append([x,y])

# """Hexagon"""

# def hex_obs():
#     global map_obs4, x_h, y_h, x_h_nc, y_h_nc, allp_map
#     x_h = []
#     y_h = []
#     x_h_nc = []
#     y_h_nc = []
#     map_obs4 = np.copy(map_obs2)
#     for x in range(int(148/Rat), int(252/Rat)):
#         for y in range(int(30/Rat),int(165/Rat)):
#             #with clearance
#             if (y - (5/8)*x + 81/Rat)>=0 and (y + (5/8)*x - 281/Rat)<=0 and (y - (5/8)*x - 31/Rat)<=0 and (y + (5/8)*x - 169/Rat)>=0 and (x - 249/Rat)<=0 and (x - 150/Rat)>=0:
#                 map_obs4[y,x,:] = -1
#                 x_h.append(x)
#                 y_h.append(y)
#                 # allp_map.append([x,y])
#                 #without clearance
#             if (y - (4/7)*x + (380/7)/Rat)>=0 and (y + (4/7)*x - 1780/7/Rat)<=0 and (y - (4/7)*x - (180/7)/Rat)<=0 and (y + (4/7)*x - (1220/7)/Rat)>=0 and (x - 234/Rat)<=0 and (x - 165/Rat)>=0:
#                 map_obs4[y,x,:] = -1
#                 x_h_nc.append(x)
#                 y_h_nc.append(y)
#                 allp_map.append([x,y])

# """The main algorithm

# Data structure
# """

# class Node:
#     def __init__(self, node_id, node_loc, parent_id, c2c , c2g):
#         self.parent_id = parent_id #
#         self.node_id = node_id #unique node id for each node
#         self.node_loc = node_loc ## [y,x,angle]
#         self.c2c= round(c2c,0)
#         self.c2g=round(c2g,2)
#         self.total_cost = round(c2c+c2g,2)

# def pop(Closed_list, Open_list, All_list):
#     dat = Open_list.get()
#     #dat[0] is c2c+c2g, dat[1] is Node_id--> starts from 1, list starts from 0 
#     Closed_list.append(All_list[dat[1]-1]) #indexing the node from the all_list  
#     ##check for goal
#     print('closed list updated')
#     if All_list[dat[1]-1].node_loc in goal_list:
#         goal_id=dat[1]-1
#         print('this will be done at', All_list[dat[1]-1].node_loc )
#         print('the goal coast is', All_list[dat[1]-1].total_cost)
#         return "Goal found", goal_id
#     return 1, All_list[dat[1]-1]

# """Cost Dictionary"""

# cost_direction = {'S': 1, 'D': 1}

# """Parameter update"""

# def param(All_list, Open_list, map_obs4, cost_dir, n_c, n_d,ang, node):
#      id = All_list[-1].node_id + 1
#      map_obs4[n_c,n_d,int(ang/30)] = id  ## id is updated in map
#      c2_g=c2g([n_c,n_d],goal_location[0:2])
#      c2c=node.c2c+cost_dir
#      cost = c2c+c2_g  #cost_dir is a dictionary
#      parent = node.node_id
#      loc = [n_c, n_d, int(ang/30)]
#      # print('node at id', id, 'cost is', cost, 'loc', loc)
#      All_list.append(Node(id, loc, parent, c2c,c2_g)) ## node is created
#      tup_new = [cost, id]
#      Open_list.put(tup_new) ## list of [cost, id] ###gives the [cost,id] in priority queue open list

# """List cost update function

# All cost needs to be rounded off to 2 due to euclidean distance
# """

# def cost_update(nod, n_c ,n_d, ang, All_list,  Closed_list, Open_list, map_obs4, cost_dir):
#      index = int(map_obs4[n_c, n_d, int(ang/30)])
#      if round((nod.c2c + cost_dir),1)< round(All_list[index-1].c2c,1): #since index/node_id is starting from 1
#             All_list[index-1].c2c = round((nod.c2c + cost_dir),1)
#             All_list[index-1].parent_id = nod.node_id
#             print('updated cost of node', index, 'is', All_list[index-1].total_cost)
#             if Open_list.qsize() > 0:
#                 for j in Open_list.queue:
#                     if j[1] ==index:
#                             j[0] = round((nod.c2c + cost_dir),1)
#                             # i.parent_id = nod.node_id


# def move_zero(node, All_list, Open_list, k):
#     a,b, node_k =node.node_loc
#     angle=node_k*30
#     ang=(angle+k*30)%360
#     c= a + (L*np.sin(ang*(np.pi/180)))/Rat #needs to be according to the matrix
#     d= b + (L*np.cos(ang*(np.pi/180)))/Rat
#     n_c, n_d=thres_round(c,d)
#     print(n_c, n_d, ang)
#     if 0<=(n_c)<=(y_size-1) and 0<=n_d<=(x_size-1) and (a!=c) and (b!=d): 
#         if map_obs4[n_c,n_d,int(ang/30)]==-2:
#             param(All_list, Open_list, map_obs4, cost_direction['S'], n_c, n_d, ang, node) 
#             print('node created with id', All_list[-1].node_id)
#             return print('node created at', All_list[-1].node_loc)
            
#         elif map_obs4[n_c,n_d, int(ang/30)]==-1:
#             print('Obstacle space')
#             return None
        
#         else:
#             print('Node exists, checking cost...')
#             cost_update(node, n_c ,n_d,ang, All_list,  Closed_list, Open_list, map_obs4, cost_direction['S'])  
#             return None
#     else:
#         return None

# def thres_round(c,d):
#     # Rat=0.5
#     n_c=np.round(c,0)
#     n_d=np.round(d,0)

#     return int(n_c),int(n_d)

# def movement(node, All_list, Open_list):
#     move_zero(node, All_list, Open_list,0)
#     print('move 0')
#     move_zero(node, All_list, Open_list,-1)
#     print('move 1')
#     move_zero(node, All_list, Open_list,-2)
#     print('move 2')
#     move_zero(node, All_list, Open_list,1)
#     print('move 3')
#     move_zero(node, All_list, Open_list,2)
#     print('move 4')

# """considering a radius of 1.5 for goal space:"""

# #passed input is as per the user
# def goal_space(goal_x, goal_y, k):
#     centre_x = goal_x
#     centre_y = goal_y
#     goal_list = []
#     for i in range(goal_x-int(3/Rat),goal_x+int(3/Rat)):
#         for j in range(goal_y-int(3/Rat), goal_y+int(3/Rat)):
#             if (i-centre_x)**2 + (j-centre_y)**2<=2.25/Rat:
#                 goal_list.append([j,i,k])
#     return goal_list 
#     #output is as per the matrix


# def c2g(initial, final):
    
#     return np.round(np.linalg.norm(np.array(initial)-np.array(final)),2)

# """x,y-world coordinate
# x,y,k--- angle in terms of degrees
# k --- 0,11 
# angle =k*30
# """

# def initial():
#     global All_list, Closed_list, goal_location, Open_list, allp_map, goal_list
#     allp_map = []
#     All_list = []
#     Closed_list = []
#     goal_list = []
#     first_node_id = 1
#     start_cords_x = int(input("please enter the starting x coordinate between 1 and 400: \n"))
#     start_cords_y = int(input("please enter the starting y coordinate between 1 and 250: \n"))
#     start_angle=int(input("please enter the starting angle from 0 to 330 (step size of 30 degree: \n"))
#     start_k=int((start_angle/30))
#     # if start_cords_x<1 or start_cords_x>400 or start_cords_y<1 or start_cords_y>400:
#     #     print("Either wrong input or the start node is in obstacle space")
#     #     exit(0)
#     # else:
#     #     node_loc = [start_cords_y-1, start_cords_x-1]
#     start_location = [int((start_cords_y-1)/Rat), int((start_cords_x-1)/Rat), start_k]
#     goal_cords_x = int(input("please enter the goal x coordinate: \n"))
#     goal_cords_y = int(input("please enter the goal y coordinate: \n"))
#     goal_angle=int(input("please enter the goal angle from 0 to 330 (step size of 30 degree: \n"))
#     goal_k=int(goal_angle/30)
#     # if goal_cords_x<1 or goal_cords_x>400 or goal_cords_y<1 or goal_cords_y>400:
#     #     print("Either wrong input or the goal node is in obstacle space")
#     #     exit(0)
#     # else:
#     #     goal_location = [goal_cords_y-1, goal_cords_x-1] ### change
#     goal_location = [int((goal_cords_y-1)/Rat), (int(goal_cords_x-1)/Rat),goal_k]
#     goal_list = goal_space(int((goal_cords_x-1)/Rat), int((goal_cords_y-1)/Rat), goal_k)
#     map()
#     print('map is defined, initialising obstacle space')
#     circle_obs()
#     triang_obs()
#     hex_obs()
#     if map_obs4[int((start_cords_y-1)/Rat), int((start_cords_x-1)/Rat), start_k]==-1 or map_obs4[int((goal_cords_y-1)/Rat), int((goal_cords_x-1)/Rat), goal_k]==-1:
#         print("start or goal node in obstacle space")
#         exit(0)
#     else:
#         map_obs4[int((start_cords_y-1)/Rat), int((start_cords_x-1)/Rat), start_k] = first_node_id
#         first_parent_id = 0
#         initial_c2g=c2g(start_location[0:2], goal_location[0:2])
#         first_cost = 0+initial_c2g
#         All_list.append(Node(first_node_id, start_location, first_parent_id,0,initial_c2g))
#         tup = [first_cost, first_node_id] # just the cost and node id, access the node using all visited and node id
#         Open_list = PriorityQueue()
#         Open_list.put(tup)

# Rat = 0.5 #unit per node
# L=1 #can be from 1 to 10
# initial()




# """Take the input from user"""

# ##goal_cost = np.inf
# while(1):
#     if (Open_list.qsize()>0):
        

#         print('inside while')
#         r,node =pop(Closed_list, Open_list, All_list)
#         print('all list length is', len(All_list))
#         if type(r) == str:
#             print('done')
#             goal_id=node
#             break
#         else:
#             print('popped')
#             movement(node, All_list, Open_list)   
#     else:
#         print('open list empty')
#         break

# def backtrack(A_list, x, y):
#     ind = int(map_obs4[All_list[goal_id].node_loc[0], All_list[goal_id].node_loc[1],All_list[goal_id].node_loc[2]])
#     y.append(A_list[ind-1].node_loc[0])
#     x.append(A_list[ind-1].node_loc[1])
#     id = A_list[ind-1].parent_id
#     while(id>0):
#         x.append(A_list[id-1].node_loc[0])
#         y.append(A_list[id-1].node_loc[1])
#         id = A_list[id - 1].parent_id

# if (map_obs4[All_list[goal_id].node_loc[0], All_list[goal_id].node_loc[1],All_list[goal_id].node_loc[2]]!=-1 and map_obs4[All_list[goal_id].node_loc[0], All_list[goal_id].node_loc[1],All_list[goal_id].node_loc[2]]!=-2 ):
#     x_a = []
#     y_a = []
#     backtrack(All_list, y_a, x_a)
#     plt.axis([0, 400/Rat, 0, 250/Rat])
#     plt.plot(x_a,y_a)
#     plt.plot(x_nc, y_nc)
#     plt.plot(x_t1_nc,y_t1_nc)
#     plt.plot(x_t2_nc,y_t2_nc)
#     plt.plot(x_h_nc,y_h_nc)
#     plt.show()
# else:
#     print('cannot be back tracked')

# x_plot = []
# y_plot = []


# #wxplored path
# for i in All_list:
    
#     x_plot.append(i.node_loc[1])
#     y_plot.append(i.node_loc[0])
   
# plt.axis([0, 400/Rat, 0, 250/Rat])
# plt.scatter(x_plot,y_plot)
# plt.plot(x_nc, y_nc)
# plt.plot(x_t1_nc,y_t1_nc)
# plt.plot(x_t2_nc,y_t2_nc)
# plt.plot(x_h_nc,y_h_nc)
# plt.show()

# %%
# import cv2
# import pygame


# # Put animation here

# #creating an empty canvas
# canvas = np.zeros((int(250/Rat),int(400/Rat),3),np.uint8)

# #list of all obstacles to put in canvas
# for c in allp_map: #change the name of the variable l
#     x = c[1]
#     y = c[0]
#     canvas[(x,y)]=[0,255,255] #assigning a yellow coloured pixel
# canvas = np.flipud(canvas)
# canvas_for_backtrack = canvas.copy()
# canvas_for_visited = canvas.copy()
# canvas_for_visited = cv2.resize(canvas_for_visited,(1200,750))
# # #showing the obstacle map
# cv2.imshow('canvas',canvas)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# pygame.init()

# display_width = int(400/Rat)
# display_height = int(250/Rat)

# gameDisplay = pygame.display.set_mode((display_width,display_height),0, 100)
# pygame.display.set_caption('Visited Nodes- Animation')
# black = (0,0,0)
# white = (0,255,255)
# surf = pygame.surfarray.make_surface(canvas_for_visited)

# clock = pygame.time.Clock()
# done = False
# while not done:
#     for event in pygame.event.get():  
#         if event.type == pygame.QUIT:  
#             done = True  
 
#     gameDisplay.fill(black)
#     for i in range(len(All_list)):
#             p_id = All_list[i].parent_id
#             if(i>0):
#                 x_start = All_list[p_id -1].node_loc[1]
#                 y1_start = All_list[p_id -1].node_loc[0]
#                 y_start = abs(display_height-1-y1_start)
#                 # print(x_start, y_start)
#             else:
#                 x_start = All_list[p_id].node_loc[1]
#                 y1_start = All_list[p_id].node_loc[0]
#                 y_start = abs(display_height-1-y1_start)
            
#             x = All_list[i].node_loc[1]
#             y1 = All_list[i].node_loc[0]
#             y = abs(display_height-1-y1)
#             # print(x_start, y_start   )
#             print(x, y, '/n')
#             pygame.draw.line(gameDisplay, white, (x_start,y_start),(x,y), 2)
#             pygame.display.flip()
#             pygame.time.wait(5)
   
#     # for i in range(len(x_a)):
#     #     pygame.time.wait(5)
#     #     x = y_a[i]
#     #     y2 = x_a[i]
#     #     y = abs(249-y2)
#     #     pygame.draw.rect(gameDisplay, (255,0,0), [x,y,1,1])
#     #     pygame.display.flip()
#     #     pygame.time.wait(5)
#     done = True
# pygame.quit()

# %%
# #visited path
# for i in range(len(All_list)):
#     x = All_list[i].node_loc[1]
#     y1 = All_list[i].node_loc[0]
#     canvas_for_backtrack[(249-y1,x)]=[255,0,0]
# tracked = cv2.resize(canvas_for_backtrack,(1200,750))
# cv2.imshow('visited nodes',tracked)
# cv2.waitKey(0)
# cv2.destroyAllWindows()


# #backtracked path
# for i in range(len(x_a)):
#     x = y_a[i]
#     y2 = x_a[i]
#     # y = abs(249-y2)
#     canvas_for_backtrack[(249-y2,x)]=[0,255,0]
# #showing the final backtracked path
# tracked = cv2.resize(canvas_for_backtrack,(1200,750))
# cv2.imshow('tracked path',tracked)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# Iteration 5

# %%
import numpy as np
import sympy as sp
import os
from queue import PriorityQueue

import matplotlib.pyplot as plt
import cv2
import pygame

#node size ratio (unit/node)
def map():
    global x_size, y_size, map_def
   
    x_size = int(400/Rat) #x and y  as per gloabl coordinate system and not matrix
    y_size = int(250/Rat)
    map_def = np.zeros((y_size,x_size,12))
    map_def[:,:,:] = -2

"""Common obstacle code"""



"""Circle"""

#x is column and y is row for the matrix
def circle_obs():
    global x_c, y_c, x_nc, y_nc, map_obs1, allp_map, y_centre, x_centre, radius
    x_c = []
    y_c = []
    x_nc = []
    y_nc = []
    y_centre = int((249 - 65)/Rat)
    x_centre = int((399 - 100)/Rat)
    radius_c = int(55/Rat) #radius of cicle including clearance
    radius = int(40/Rat)
    map_obs1 = np.copy(map_def) # a deep copy #chnage this to map_obs1
    for x in range(int(240/Rat),int(360/Rat)):
        for y in range(int(120/Rat), int(240/Rat)):
            if (np.sqrt((x-x_centre)**2 + (y-y_centre)**2)) < radius_c:
                map_obs1[y, x,:] = -1 #obstacle space updated as -1
                x_c.append(x) #to be used for plotting
                y_c.append(y)
                allp_map.append([x,y]) #to be used for visualisation on pygame
            if (np.sqrt((x-x_centre)**2 + (y-y_centre)**2)) < radius:
                x_nc.append(x) #list of obstacle without clearance
                y_nc.append(y)

"""Triangles"""
def triang_obs():
    global x_t1, y_t1, x_t1_nc, y_t1_nc, map_obs2, x_t2_nc, y_t2_nc, x_t2, y_t2, allp_map, Rat
    x_t1 = []
    y_t1 = []
    x_t2 = []
    y_t2 = []
    x_t1_nc = []
    y_t1_nc = []
    x_t2_nc = []
    y_t2_nc = []
    map_obs2 = np.copy(map_obs1)
    for x in range(int(170/Rat)):
        for y in range(int(40*Rat),int(240/Rat)):
            if (y - (6/7)*x - ((779/7) + 15)/Rat)<=0 and (y - (-85/69)*x - ((15880/69) -18)/Rat)>=0 and (y - (-16/5)*x - ((2169/5) +25)/Rat)<=0 :
                map_obs2[y,x,:] = -1
                x_t1.append(x)
                y_t1.append(y)
                allp_map.append([x,y])
            if (y - (6/7)*x - ((779/7))/Rat)<=0 and (y - (-85/69)*x - ((15880/69))/Rat)>=0 and (y - (-16/5)*x - ((2169/5) +10)/Rat)<=0 :
                map_obs2[y,x,:] = -1
                x_t1_nc.append(x)
                y_t1_nc.append(y)
                allp_map.append([x,y])
            if (y - (6/7)*x - ((779/7) - 15)/Rat)>=0 and (y - (-85/69)*x - ((15880/69) -18)/Rat)>=0 and (y - (25/79)*x - ((13661/79) +15)/Rat)<=0:
                map_obs2[y,x,:] = -1
                x_t2.append(x)
                y_t2.append(y)
                allp_map.append([x,y])
            if (y - (6/7)*x - ((779/7) )/Rat)>=0 and (y - (-85/69)*x - ((15880/69))/Rat)>=0 and (y - (25/79)*x - ((13661/79))/Rat)<=0:
                map_obs2[y,x,:] = -1
                x_t2_nc.append(x)
                y_t2_nc.append(y)
                allp_map.append([x,y])

"""Hexagon"""

def hex_obs():
    global map_obs4, x_h, y_h, x_h_nc, y_h_nc, allp_map
    x_h = []
    y_h = []
    x_h_nc = []
    y_h_nc = []
    map_obs4 = np.copy(map_obs2)
    for x in range(int(148/Rat), int(252/Rat)):
        for y in range(int(30/Rat),int(165/Rat)):
            if (y - (5/8)*x + 81/Rat)>=0 and (y + (5/8)*x - 281/Rat)<=0 and (y - (5/8)*x - 31/Rat)<=0 and (y + (5/8)*x - 169/Rat)>=0 and (x - 249/Rat)<=0 and (x - 150/Rat)>=0:
                map_obs4[y,x,:] = -1
                x_h.append(x)
                y_h.append(y)
                allp_map.append([x,y])
            if (y - (4/7)*x + (380/7)/Rat)>=0 and (y + (4/7)*x - 1780/7/Rat)<=0 and (y - (4/7)*x - (180/7)/Rat)<=0 and (y + (4/7)*x - (1220/7)/Rat)>=0 and (x - 234/Rat)<=0 and (x - 165/Rat)>=0:
                map_obs4[y,x,:] = -1
                x_h_nc.append(x)
                y_h_nc.append(y)
                allp_map.append([x,y])

"""The main algorithm

Data structure
"""

class Node:
    def __init__(self, node_id, node_loc, parent_id, c2c , c2g):
        self.parent_id = parent_id #
        self.node_id = node_id #unique node id for each node
        self.node_loc = node_loc ## [y,x,angle]
        self.c2c= round(c2c,0)
        self.c2g=round(c2g,2)
        self.total_cost = round(c2c+c2g,2)

def pop(Closed_list, Open_list, All_list):
    dat = Open_list.get()
    #dat[0] is c2c+c2g, dat[1] is Node_id--> starts from 1, list starts from 0 
    Closed_list.append(All_list[dat[1]-1]) #indexing the node from the all_list  
    ##check for goal
    print('closed list updated')
    if All_list[dat[1]-1].node_loc in goal_list:
        goal_id=dat[1]-1
        print('this will be done at', All_list[dat[1]-1].node_loc )
        print('the goal coast is', All_list[dat[1]-1].total_cost)
        return "Goal found", goal_id
    return 1, All_list[dat[1]-1]

"""Cost Dictionary"""

cost_direction = {'S': 1, 'D': 1}

"""Parameter update"""

def param(All_list, Open_list, map_obs4, cost_dir, n_c, n_d,ang, node):
     id = All_list[-1].node_id + 1
     map_obs4[n_c,n_d,int(ang/30)] = id  ## id is updated in map
     c2_g=c2g([n_c,n_d],goal_location[0:2])
     c2c=node.c2c+cost_dir
     cost = c2c+c2_g  #cost_dir is a dictionary
     parent = node.node_id
     loc = [n_c, n_d, int(ang/30)]
     # print('node at id', id, 'cost is', cost, 'loc', loc)
     All_list.append(Node(id, loc, parent, c2c,c2_g)) ## node is created
     tup_new = [cost, id]
     Open_list.put(tup_new) ## list of [cost, id] ###gives the [cost,id] in priority queue open list

"""List cost update function

All cost needs to be rounded off to 2 due to euclidean distance
"""

def cost_update(nod, n_c ,n_d, ang, All_list,  Closed_list, Open_list, map_obs4, cost_dir):
     index = int(map_obs4[n_c, n_d, int(ang/30)])
     if round((nod.c2c + cost_dir),1)< round(All_list[index-1].c2c,1): #since index/node_id is starting from 1
            All_list[index-1].c2c = round((nod.c2c + cost_dir),1)
            All_list[index-1].parent_id = nod.node_id
            print('updated cost of node', index, 'is', All_list[index-1].total_cost)
            if Open_list.qsize() > 0:
                for j in Open_list.queue:
                    if j[1] ==index:
                            j[0] = round((nod.c2c + cost_dir),1)
                            # i.parent_id = nod.node_id


def move_zero(node, All_list, Open_list, k):
    a,b, node_k =node.node_loc
    angle=node_k*30
    ang=(angle+k*30)%360
    c= a + (L*np.sin(ang*(np.pi/180)))/Rat #needs to be according to the matrix
    d= b + (L*np.cos(ang*(np.pi/180)))/Rat
    n_c, n_d=thres_round(c,d)
    # print(n_c, n_d, ang)
    if 0<=(n_c)<=(y_size-1) and 0<=n_d<=(x_size-1) and (a!=c) and (b!=d): 
        if map_obs4[n_c,n_d,int(ang/30)]==-2:
            param(All_list, Open_list, map_obs4, cost_direction['S'], n_c, n_d, ang, node) 
            print('node created with id', All_list[-1].node_id)
            return print('node created at', All_list[-1].node_loc)
            
        elif map_obs4[n_c,n_d, int(ang/30)]==-1:
            print('Obstacle space')
            return None
        
        else:
            print('Node exists, checking cost...')
            cost_update(node, n_c ,n_d,ang, All_list,  Closed_list, Open_list, map_obs4, cost_direction['S'])  
            return None
    else:
        return None

def thres_round(c,d):
    # Rat=0.5
    n_c=np.round(c,0)
    n_d=np.round(d,0)

    return int(n_c),int(n_d)

def movement(node, All_list, Open_list):
    move_zero(node, All_list, Open_list,0)
    print('move 0')
    move_zero(node, All_list, Open_list,-1)
    print('move 1')
    move_zero(node, All_list, Open_list,-2)
    print('move 2')
    move_zero(node, All_list, Open_list,1)
    print('move 3')
    move_zero(node, All_list, Open_list,2)
    print('move 4')

"""considering a radius of 1.5 for goal space:"""

#passed input is as per the user
def goal_space(goal_x, goal_y, k):
    centre_x = goal_x
    centre_y = goal_y
    goal_list = []
    for i in range(goal_x-int(3/Rat),goal_x+int(3/Rat)):
        for j in range(goal_y-int(3/Rat), goal_y+int(3/Rat)):
            if (i-centre_x)**2 + (j-centre_y)**2<=(2.25/Rat)*L:
                goal_list.append([j,i,k])
    return goal_list 
    #output is as per the matrix
def backtrack(A_list, x, y):
    ind = int(map_obs4[All_list[goal_id].node_loc[0], All_list[goal_id].node_loc[1],All_list[goal_id].node_loc[2]])
    y.append(A_list[ind-1].node_loc[0])
    x.append(A_list[ind-1].node_loc[1])
    id = A_list[ind-1].parent_id
    while(id>0):
        x.append(A_list[id-1].node_loc[0])
        y.append(A_list[id-1].node_loc[1])
        id = A_list[id - 1].parent_id

def c2g(initial, final):
    
    return np.round(np.linalg.norm(np.array(initial)-np.array(final)),2)

"""x,y-world coordinate
x,y,k--- angle in terms of degrees
k --- 0,11 
angle =k*30
"""
def display_path(goal_id):
    global x_a, y_a
    if (map_obs4[All_list[goal_id].node_loc[0], All_list[goal_id].node_loc[1],All_list[goal_id].node_loc[2]]!=-1 and map_obs4[All_list[goal_id].node_loc[0], All_list[goal_id].node_loc[1],All_list[goal_id].node_loc[2]]!=-2 ):
                x_a = []
                y_a = []
                backtrack(All_list, y_a, x_a)
                # y_a.reverse()
                # x_a.reverse()
                plt.axis([0, 400/Rat, 0, 250/Rat])
                plt.plot(x_a,y_a)
                plt.plot(x_nc, y_nc)
                plt.plot(x_t1_nc,y_t1_nc)
                plt.plot(x_t2_nc,y_t2_nc)
                plt.plot(x_h_nc,y_h_nc)
                plt.show()
    else:
        print('cannot be back tracked')
        exit(0)

    x_plot = []
    y_plot = []


    #wxplored path
    for i in All_list:
        
        x_plot.append(i.node_loc[1])
        y_plot.append(i.node_loc[0])
    
    plt.axis([0, 400/Rat, 0, 250/Rat])
    plt.scatter(x_plot,y_plot)
    plt.plot(x_nc, y_nc)
    plt.plot(x_t1_nc,y_t1_nc)
    plt.plot(x_t2_nc,y_t2_nc)
    plt.plot(x_h_nc,y_h_nc)
    plt.show()

def display():

    # Put animation here

    #creating an empty canvas
    canvas = np.zeros((int(250/Rat),int(400/Rat),3),np.uint8)

    #list of all obstacles to put in canvas
    for c in allp_map: #change the name of the variable l
        x = c[1]
        y = c[0]
        canvas[(x,y)]=[0,255,255] #assigning a yellow coloured pixel
    canvas = np.flipud(canvas)
    canvas_for_backtrack = canvas.copy()
    canvas_for_visited = canvas.copy()
    canvas_for_visited = cv2.resize(canvas_for_visited,(1200,750))
    # #showing the obstacle map
    cv2.imshow('canvas',canvas)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    pygame.init()

    display_width = int(400/Rat)
    display_height = int(250/Rat)
    n = 2
    m = n
    # gameDisplay = pygame.display.set_mode((display_width,display_height),0, 32, 0, 10)
    gameDisplay = pygame.display.set_mode((n*display_width,n*display_height))
    # gameDisplay = pygame.display.set_mode((1920,1080),flags, vsync =1)
    # gameDisplay = pygame.display.set_mode((0,0),pygame.FULLSCREEN)
    pygame.display.set_caption('Visited Nodes- Animation')
    black = (0,0,0)
    white = (255,255,255)
    y = (255, 0,0)
    surf = pygame.surfarray.make_surface(canvas_for_visited)

    clock = pygame.time.Clock()
    done = False
    while not done:
        for event in pygame.event.get():  
            if event.type == pygame.QUIT:  
                done = True  
    
        gameDisplay.fill(black)
        for i in range(len(All_list)):
                p_id = All_list[i].parent_id
                if(i>0):
                    x_start = All_list[p_id -1].node_loc[1]
                    y1_start = All_list[p_id -1].node_loc[0]
                    y_start = abs(display_height-1-y1_start)
                    # print(x_start, y_start)
                else:
                    x_start = All_list[p_id].node_loc[1]
                    y1_start = All_list[p_id].node_loc[0]
                    y_start = abs(display_height-1-y1_start)
                
                x = All_list[i].node_loc[1]
                y1 = All_list[i].node_loc[0]
                y = abs(display_height-1-y1)
                # print(x_start, y_start   )
                # print(x, y)
                pygame.draw.line(gameDisplay, white, (n*x_start,n*y_start),(m*x,m*y), 1)
                pygame.display.flip()
                pygame.time.wait(4)

        ind = int(map_obs4[All_list[goal_id].node_loc[0], All_list[goal_id].node_loc[1],All_list[goal_id].node_loc[2]])
        for i in range(len(x_a)-1):
                # pygame.time.wait(5)
                
                # y = (All_list[ind-1].node_loc[0])
                # x = (All_list[ind-1].node_loc[1])
                # id = All_list[ind-1].parent_id
                # y_parent = (All_list[id-1].node_loc[0])
                # x_parent = (All_list[id-1].node_loc[0])
                # while(id>0):
                #     x.append(All_list[id-1].node_loc[0])
                #     y.append(All_list[id-1].node_loc[1])
                # id = All_list[id - 1].parent_id
                pygame.draw.line(gameDisplay, y, (n*x_a[i],n*(display_height-y_a[i])),(n*x_a[i+1],n*(display_height-y_a[i+1])), 3)
                pygame.display.flip()
                pygame.time.wait(4)
        done = True
        
        pygame.time.delay(20)
        pygame.quit()

def initial():
    global All_list, Closed_list, goal_location, Open_list, allp_map, goal_list, L
    allp_map = []
    All_list = []
    Closed_list = []
    goal_list = []
    first_node_id = 1
    start_cords_x = int(input("please enter the starting x coordinate between 1 and 400: \n"))
    start_cords_y = int(input("please enter the starting y coordinate between 1 and 250: \n"))
    start_angle=int(input("please enter the starting angle from 0 to 330 (step size of 30 degree: \n"))
    start_k=int((start_angle/30))
    if start_cords_x<1 or start_cords_x>400 or start_cords_y<1 or start_cords_y>400:
        print("Either wrong input or the start node is in obstacle space")
        exit(0)
    else:
        start_location = [int((start_cords_y-1)/Rat), int((start_cords_x-1)/Rat), start_k]
    
    goal_cords_x = int(input("please enter the goal x coordinate: \n"))
    goal_cords_y = int(input("please enter the goal y coordinate: \n"))
    goal_angle=int(input("please enter the goal angle from 0 to 330 (step size of 30 degree: \n"))
    goal_k=int(goal_angle/30)
    if goal_cords_x<1 or goal_cords_x>400 or goal_cords_y<1 or goal_cords_y>400:
        print("Either wrong input or the goal node is in obstacle space")
        exit(0)
    else:
        goal_location = [int((goal_cords_y-1)/Rat), (int(goal_cords_x-1)/Rat),goal_k]
    L = int(input("Enter the value of step size between (1-10): \n"))
    goal_list = goal_space(int((goal_cords_x-1)/Rat), int((goal_cords_y-1)/Rat), goal_k)

    map()
    print('map is defined, initialising obstacle space')
    circle_obs()
    triang_obs()
    hex_obs()
    if map_obs4[int((start_cords_y-1)/Rat), int((start_cords_x-1)/Rat), start_k]==-1 or map_obs4[int((goal_cords_y-1)/Rat), int((goal_cords_x-1)/Rat), goal_k]==-1:
        print("start or goal node in obstacle space")
        exit(0)
    else:
        map_obs4[int((start_cords_y-1)/Rat), int((start_cords_x-1)/Rat), start_k] = first_node_id
        first_parent_id = 0
        initial_c2g=c2g(start_location[0:2], goal_location[0:2])
        first_cost = 0+initial_c2g
        All_list.append(Node(first_node_id, start_location, first_parent_id,0,initial_c2g))
        tup = [first_cost, first_node_id] # just the cost and node id, access the node using all visited and node id
        Open_list = PriorityQueue()
        Open_list.put(tup)



Rat = 0.5 #unit per node
# L=4 #can be from 1 to 10
initial()
# Out:
# pygame 2.1.2 (SDL 2.0.16, Python 3.7.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# map is defined, initialising obstacle space

# %%
goal_list
# Out:
# [[496, 794, 11],
#  [497, 794, 11],
#  [498, 794, 11],
#  [499, 794, 11],
#  [500, 794, 11],
#  [495, 795, 11],
#  [496, 795, 11],
#  [497, 795, 11],
#  [498, 795, 11],
#  [499, 795, 11],
#  [500, 795, 11],
#  [501, 795, 11],
#  [494, 796, 11],
#  [495, 796, 11],
#  [496, 796, 11],
#  [497, 796, 11],
#  [498, 796, 11],
#  [499, 796, 11],
#  [500, 796, 11],
#  [501, 796, 11],
#  [502, 796, 11],
#  [494, 797, 11],
#  [495, 797, 11],
#  [496, 797, 11],
#  [497, 797, 11],
#  [498, 797, 11],
#  [499, 797, 11],
#  [500, 797, 11],
#  [501, 797, 11],
#  [502, 797, 11],
#  [494, 798, 11],
#  [495, 798, 11],
#  [496, 798, 11],
#  [497, 798, 11],
#  [498, 798, 11],
#  [499, 798, 11],
#  [500, 798, 11],
#  [501, 798, 11],
#  [502, 798, 11],
#  [494, 799, 11],
#  [495, 799, 11],
#  [496, 799, 11],
#  [497, 799, 11],
#  [498, 799, 11],
#  [499, 799, 11],
#  [500, 799, 11],
#  [501, 799, 11],
#  [502, 799, 11],
#  [494, 800, 11],
#  [495, 800, 11],
#  [496, 800, 11],
#  [497, 800, 11],
#  [498, 800, 11],
#  [499, 800, 11],
#  [500, 800, 11],
#  [501, 800, 11],
#  [502, 800, 11],
#  [495, 801, 11],
#  [496, 801, 11],
#  [497, 801, 11],
#  [498, 801, 11],
#  [499, 801, 11],
#  [500, 801, 11],
#  [501, 801, 11],
#  [496, 802, 11],
#  [497, 802, 11],
#  [498, 802, 11],
#  [499, 802, 11],
#  [500, 802, 11]]

# %%
"""Take the input from user"""

##goal_cost = np.inf
while(1):
    if (Open_list.qsize()>0):
        

        print('inside while')
        r,node =pop(Closed_list, Open_list, All_list)
        print('all list length is', len(All_list))
        if type(r) == str:
            print('done')
            goal_id=node
            display_path(goal_id)
            # display()
            break
        else:
            print('popped')
            movement(node, All_list, Open_list)   
    else:
        print('open list empty')
        break
# Out:
# inside while
# closed list updated
# all list length is 1
# popped
# node created with id 2
# node created at [5, 9, 1]
# move 0
# move 1
# move 2
# node created with id 3
# node created at [9, 5, 2]
# move 3
# node created with id 4
# node created at [10, 0, 3]
# move 4
# inside while
# closed list updated
# all list length is 4
# popped
# node created with id 5
# node created at [10, 18, 1]
# move 0
# move 1
# node created with id 6
# node created at [0, 18, 11]
# move 2
# node created with id 7
# node created at [14, 14, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 7
# popped
# node created with id 8
# node created at [15, 27, 1]
# move 0
# move 1
# node created with id 9
# node created at [5, 27, 11]
# move 2
# node created with id 10
# node created at [19, 23, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 10
# popped
# node created with id 11
# node created at [20, 36, 1]
# move 0
# move 1
# node created with id 12
# node created at [10, 36, 11]
# move 2
# node created with id 13
# node created at [24, 32, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 13
# popped
# node created with id 14
# node created at [25, 45, 1]
# move 0
# move 1
# node created with id 15
# node created at [15, 45, 11]
# move 2
# node created with id 16
# node created at [29, 41, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 16
# popped
# node created with id 17
# node created at [30, 54, 1]
# move 0
# move 1
# node created with id 18
# node created at [20, 54, 11]
# move 2
# node created with id 19
# node created at [34, 50, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 19
# popped
# node created with id 20
# node created at [35, 63, 1]
# move 0
# move 1
# node created with id 21
# node created at [25, 63, 11]
# move 2
# node created with id 22
# node created at [39, 59, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 22
# popped
# node created with id 23
# node created at [40, 72, 1]
# move 0
# move 1
# node created with id 24
# node created at [30, 72, 11]
# move 2
# node created with id 25
# node created at [44, 68, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 25
# popped
# node created with id 26
# node created at [45, 81, 1]
# move 0
# move 1
# node created with id 27
# node created at [35, 81, 11]
# move 2
# node created with id 28
# node created at [49, 77, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 28
# popped
# node created with id 29
# node created at [50, 90, 1]
# move 0
# move 1
# node created with id 30
# node created at [40, 90, 11]
# move 2
# node created with id 31
# node created at [54, 86, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 31
# popped
# node created with id 32
# node created at [55, 99, 1]
# move 0
# move 1
# node created with id 33
# node created at [45, 99, 11]
# move 2
# node created with id 34
# node created at [59, 95, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 34
# popped
# node created with id 35
# node created at [60, 108, 1]
# move 0
# move 1
# node created with id 36
# node created at [50, 108, 11]
# move 2
# node created with id 37
# node created at [64, 104, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 37
# popped
# node created with id 38
# node created at [65, 117, 1]
# move 0
# move 1
# node created with id 39
# node created at [55, 117, 11]
# move 2
# node created with id 40
# node created at [69, 113, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 40
# popped
# node created with id 41
# node created at [70, 126, 1]
# move 0
# move 1
# node created with id 42
# node created at [60, 126, 11]
# move 2
# node created with id 43
# node created at [74, 122, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 43
# popped
# node created with id 44
# node created at [75, 135, 1]
# move 0
# move 1
# node created with id 45
# node created at [65, 135, 11]
# move 2
# node created with id 46
# node created at [79, 131, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 46
# popped
# node created with id 47
# node created at [80, 144, 1]
# move 0
# move 1
# node created with id 48
# node created at [70, 144, 11]
# move 2
# node created with id 49
# node created at [84, 140, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 49
# popped
# node created with id 50
# node created at [85, 153, 1]
# move 0
# move 1
# node created with id 51
# node created at [75, 153, 11]
# move 2
# node created with id 52
# node created at [89, 149, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 52
# popped
# node created with id 53
# node created at [90, 162, 1]
# move 0
# move 1
# node created with id 54
# node created at [80, 162, 11]
# move 2
# node created with id 55
# node created at [94, 158, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 55
# popped
# node created with id 56
# node created at [95, 171, 1]
# move 0
# move 1
# node created with id 57
# node created at [85, 171, 11]
# move 2
# node created with id 58
# node created at [99, 167, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 58
# popped
# node created with id 59
# node created at [100, 180, 1]
# move 0
# move 1
# node created with id 60
# node created at [90, 180, 11]
# move 2
# node created with id 61
# node created at [104, 176, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 61
# popped
# node created with id 62
# node created at [105, 189, 1]
# move 0
# move 1
# node created with id 63
# node created at [95, 189, 11]
# move 2
# node created with id 64
# node created at [109, 185, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 64
# popped
# node created with id 65
# node created at [110, 198, 1]
# move 0
# move 1
# node created with id 66
# node created at [100, 198, 11]
# move 2
# node created with id 67
# node created at [114, 194, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 67
# popped
# node created with id 68
# node created at [115, 207, 1]
# move 0
# move 1
# node created with id 69
# node created at [105, 207, 11]
# move 2
# node created with id 70
# node created at [119, 203, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 70
# popped
# node created with id 71
# node created at [120, 216, 1]
# move 0
# move 1
# node created with id 72
# node created at [110, 216, 11]
# move 2
# node created with id 73
# node created at [124, 212, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 73
# popped
# node created with id 74
# node created at [125, 225, 1]
# move 0
# move 1
# node created with id 75
# node created at [115, 225, 11]
# move 2
# node created with id 76
# node created at [129, 221, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 76
# popped
# node created with id 77
# node created at [130, 234, 1]
# move 0
# move 1
# node created with id 78
# node created at [120, 234, 11]
# move 2
# node created with id 79
# node created at [134, 230, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 79
# popped
# Obstacle space
# move 0
# move 1
# Obstacle space
# move 2
# Obstacle space
# move 3
# move 4
# inside while
# closed list updated
# all list length is 79
# popped
# Obstacle space
# move 0
# Obstacle space
# move 1
# move 2
# move 3
# node created with id 80
# node created at [143, 225, 4]
# move 4
# inside while
# closed list updated
# all list length is 80
# popped
# node created with id 81
# node created at [152, 220, 4]
# move 0
# move 1
# Obstacle space
# move 2
# node created with id 82
# node created at [148, 216, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 82
# popped
# Obstacle space
# move 0
# move 1
# Obstacle space
# move 2
# node created with id 83
# node created at [157, 211, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 83
# popped
# node created with id 84
# node created at [115, 243, 11]
# move 0
# node created with id 85
# node created at [111, 239, 10]
# move 1
# move 2
# move 3
# Obstacle space
# move 4
# inside while
# closed list updated
# all list length is 85
# popped
# node created with id 86
# node created at [110, 252, 11]
# move 0
# node created with id 87
# node created at [106, 248, 10]
# move 1
# move 2
# move 3
# node created with id 88
# node created at [120, 252, 1]
# move 4
# inside while
# closed list updated
# all list length is 88
# popped
# node created with id 89
# node created at [125, 261, 1]
# move 0
# move 1
# node created with id 90
# node created at [115, 261, 11]
# move 2
# node created with id 91
# node created at [129, 257, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 91
# popped
# node created with id 92
# node created at [130, 270, 1]
# move 0
# move 1
# node created with id 93
# node created at [120, 270, 11]
# move 2
# node created with id 94
# node created at [134, 266, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 94
# popped
# node created with id 95
# node created at [135, 279, 1]
# move 0
# move 1
# node created with id 96
# node created at [125, 279, 11]
# move 2
# node created with id 97
# node created at [139, 275, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 97
# popped
# node created with id 98
# node created at [140, 288, 1]
# move 0
# move 1
# node created with id 99
# node created at [130, 288, 11]
# move 2
# node created with id 100
# node created at [144, 284, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 100
# popped
# node created with id 101
# node created at [145, 297, 1]
# move 0
# move 1
# node created with id 102
# node created at [135, 297, 11]
# move 2
# node created with id 103
# node created at [149, 293, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 103
# popped
# Obstacle space
# move 0
# move 1
# node created with id 104
# node created at [140, 306, 11]
# move 2
# Obstacle space
# move 3
# move 4
# inside while
# closed list updated
# all list length is 104
# popped
# node created with id 105
# node created at [135, 315, 11]
# move 0
# node created with id 106
# node created at [131, 311, 10]
# move 1
# move 2
# move 3
# Obstacle space
# move 4
# inside while
# closed list updated
# all list length is 106
# popped
# node created with id 107
# node created at [130, 324, 11]
# move 0
# node created with id 108
# node created at [126, 320, 10]
# move 1
# move 2
# move 3
# Obstacle space
# move 4
# inside while
# closed list updated
# all list length is 108
# popped
# node created with id 109
# node created at [125, 333, 11]
# move 0
# node created with id 110
# node created at [121, 329, 10]
# move 1
# move 2
# move 3
# Obstacle space
# move 4
# inside while
# closed list updated
# all list length is 110
# popped
# node created with id 111
# node created at [120, 342, 11]
# move 0
# node created with id 112
# node created at [116, 338, 10]
# move 1
# move 2
# move 3
# Obstacle space
# move 4
# inside while
# closed list updated
# all list length is 112
# popped
# node created with id 113
# node created at [115, 351, 11]
# move 0
# node created with id 114
# node created at [111, 347, 10]
# move 1
# move 2
# move 3
# Obstacle space
# move 4
# inside while
# closed list updated
# all list length is 114
# popped
# node created with id 115
# node created at [110, 360, 11]
# move 0
# node created with id 116
# node created at [106, 356, 10]
# move 1
# move 2
# move 3
# Obstacle space
# move 4
# inside while
# closed list updated
# all list length is 116
# popped
# node created with id 117
# node created at [105, 369, 11]
# move 0
# node created with id 118
# node created at [101, 365, 10]
# move 1
# move 2
# move 3
# Obstacle space
# move 4
# inside while
# closed list updated
# all list length is 118
# popped
# node created with id 119
# node created at [100, 378, 11]
# move 0
# node created with id 120
# node created at [96, 374, 10]
# move 1
# move 2
# move 3
# Obstacle space
# move 4
# inside while
# closed list updated
# all list length is 120
# popped
# node created with id 121
# node created at [95, 387, 11]
# move 0
# node created with id 122
# node created at [91, 383, 10]
# move 1
# move 2
# move 3
# Obstacle space
# move 4
# inside while
# closed list updated
# all list length is 122
# popped
# node created with id 123
# node created at [90, 396, 11]
# move 0
# node created with id 124
# node created at [86, 392, 10]
# move 1
# move 2
# move 3
# Obstacle space
# move 4
# inside while
# closed list updated
# all list length is 124
# popped
# node created with id 125
# node created at [85, 405, 11]
# move 0
# node created with id 126
# node created at [81, 401, 10]
# move 1
# move 2
# move 3
# Obstacle space
# move 4
# inside while
# closed list updated
# all list length is 126
# popped
# node created with id 127
# node created at [80, 414, 11]
# move 0
# node created with id 128
# node created at [76, 410, 10]
# move 1
# move 2
# move 3
# node created with id 129
# node created at [90, 414, 1]
# move 4
# inside while
# closed list updated
# all list length is 129
# popped
# node created with id 130
# node created at [95, 423, 1]
# move 0
# move 1
# node created with id 131
# node created at [85, 423, 11]
# move 2
# node created with id 132
# node created at [99, 419, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 132
# popped
# Obstacle space
# move 0
# node created with id 133
# node created at [104, 428, 1]
# move 1
# move 2
# move 3
# Obstacle space
# move 4
# inside while
# closed list updated
# all list length is 133
# popped
# node created with id 134
# node created at [109, 437, 1]
# move 0
# move 1
# node created with id 135
# node created at [99, 437, 11]
# move 2
# Obstacle space
# move 3
# move 4
# inside while
# closed list updated
# all list length is 135
# popped
# node created with id 136
# node created at [114, 446, 1]
# move 0
# move 1
# node created with id 137
# node created at [104, 446, 11]
# move 2
# Obstacle space
# move 3
# move 4
# inside while
# closed list updated
# all list length is 137
# popped
# node created with id 138
# node created at [119, 455, 1]
# move 0
# move 1
# node created with id 139
# node created at [109, 455, 11]
# move 2
# Obstacle space
# move 3
# move 4
# inside while
# closed list updated
# all list length is 139
# popped
# node created with id 140
# node created at [124, 464, 1]
# move 0
# move 1
# node created with id 141
# node created at [114, 464, 11]
# move 2
# Obstacle space
# move 3
# move 4
# inside while
# closed list updated
# all list length is 141
# popped
# node created with id 142
# node created at [129, 473, 1]
# move 0
# move 1
# node created with id 143
# node created at [119, 473, 11]
# move 2
# Obstacle space
# move 3
# move 4
# inside while
# closed list updated
# all list length is 143
# popped
# node created with id 144
# node created at [134, 482, 1]
# move 0
# move 1
# node created with id 145
# node created at [124, 482, 11]
# move 2
# Obstacle space
# move 3
# move 4
# inside while
# closed list updated
# all list length is 145
# popped
# node created with id 146
# node created at [139, 491, 1]
# move 0
# move 1
# node created with id 147
# node created at [129, 491, 11]
# move 2
# Obstacle space
# move 3
# move 4
# inside while
# closed list updated
# all list length is 147
# popped
# node created with id 148
# node created at [144, 500, 1]
# move 0
# move 1
# node created with id 149
# node created at [134, 500, 11]
# move 2
# Obstacle space
# move 3
# move 4
# inside while
# closed list updated
# all list length is 149
# popped
# node created with id 150
# node created at [149, 509, 1]
# move 0
# move 1
# node created with id 151
# node created at [139, 509, 11]
# move 2
# node created with id 152
# node created at [153, 505, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 152
# popped
# node created with id 153
# node created at [162, 510, 2]
# move 0
# node created with id 154
# node created at [158, 514, 1]
# move 1
# move 2
# move 3
# node created with id 155
# node created at [162, 500, 4]
# move 4
# inside while
# closed list updated
# all list length is 155
# popped
# node created with id 156
# node created at [171, 515, 2]
# move 0
# node created with id 157
# node created at [167, 519, 1]
# move 1
# move 2
# move 3
# node created with id 158
# node created at [171, 505, 4]
# move 4
# inside while
# closed list updated
# all list length is 158
# popped
# node created with id 159
# node created at [180, 520, 2]
# move 0
# node created with id 160
# node created at [176, 524, 1]
# move 1
# move 2
# move 3
# node created with id 161
# node created at [180, 510, 4]
# move 4
# inside while
# closed list updated
# all list length is 161
# popped
# node created with id 162
# node created at [189, 525, 2]
# move 0
# node created with id 163
# node created at [185, 529, 1]
# move 1
# move 2
# move 3
# node created with id 164
# node created at [189, 515, 4]
# move 4
# inside while
# closed list updated
# all list length is 164
# popped
# node created with id 165
# node created at [198, 530, 2]
# move 0
# node created with id 166
# node created at [194, 534, 1]
# move 1
# move 2
# move 3
# node created with id 167
# node created at [198, 520, 4]
# move 4
# inside while
# closed list updated
# all list length is 167
# popped
# node created with id 168
# node created at [207, 535, 2]
# move 0
# node created with id 169
# node created at [203, 539, 1]
# move 1
# move 2
# move 3
# node created with id 170
# node created at [207, 525, 4]
# move 4
# inside while
# closed list updated
# all list length is 170
# popped
# node created with id 171
# node created at [216, 540, 2]
# move 0
# node created with id 172
# node created at [212, 544, 1]
# move 1
# move 2
# move 3
# node created with id 173
# node created at [216, 530, 4]
# move 4
# inside while
# closed list updated
# all list length is 173
# popped
# node created with id 174
# node created at [225, 545, 2]
# move 0
# node created with id 175
# node created at [221, 549, 1]
# move 1
# move 2
# move 3
# node created with id 176
# node created at [225, 535, 4]
# move 4
# inside while
# closed list updated
# all list length is 176
# popped
# node created with id 177
# node created at [234, 550, 2]
# move 0
# node created with id 178
# node created at [230, 554, 1]
# move 1
# move 2
# move 3
# node created with id 179
# node created at [234, 540, 4]
# move 4
# inside while
# closed list updated
# all list length is 179
# popped
# node created with id 180
# node created at [243, 555, 2]
# move 0
# node created with id 181
# node created at [239, 559, 1]
# move 1
# move 2
# move 3
# node created with id 182
# node created at [243, 545, 4]
# move 4
# inside while
# closed list updated
# all list length is 182
# popped
# node created with id 183
# node created at [252, 560, 2]
# move 0
# node created with id 184
# node created at [248, 564, 1]
# move 1
# move 2
# move 3
# node created with id 185
# node created at [252, 550, 4]
# move 4
# inside while
# closed list updated
# all list length is 185
# popped
# node created with id 186
# node created at [261, 565, 2]
# move 0
# node created with id 187
# node created at [257, 569, 1]
# move 1
# move 2
# move 3
# node created with id 188
# node created at [261, 555, 4]
# move 4
# inside while
# closed list updated
# all list length is 188
# popped
# Obstacle space
# move 0
# Obstacle space
# move 1
# move 2
# move 3
# Obstacle space
# move 4
# inside while
# closed list updated
# all list length is 188
# popped
# Obstacle space
# move 0
# move 1
# node created with id 189
# node created at [252, 578, 11]
# move 2
# Obstacle space
# move 3
# move 4
# inside while
# closed list updated
# all list length is 189
# popped
# node created with id 190
# node created at [247, 587, 11]
# move 0
# node created with id 191
# node created at [243, 583, 10]
# move 1
# move 2
# move 3
# node created with id 192
# node created at [257, 587, 1]
# move 4
# inside while
# closed list updated
# all list length is 192
# popped
# Obstacle space
# move 0
# move 1
# node created with id 193
# node created at [252, 596, 11]
# move 2
# Obstacle space
# move 3
# move 4
# inside while
# closed list updated
# all list length is 193
# popped
# node created with id 194
# node created at [247, 605, 11]
# move 0
# node created with id 195
# node created at [243, 601, 10]
# move 1
# move 2
# move 3
# node created with id 196
# node created at [257, 605, 1]
# move 4
# inside while
# closed list updated
# all list length is 196
# popped
# Obstacle space
# move 0
# move 1
# node created with id 197
# node created at [252, 614, 11]
# move 2
# Obstacle space
# move 3
# move 4
# inside while
# closed list updated
# all list length is 197
# popped
# node created with id 198
# node created at [247, 623, 11]
# move 0
# node created with id 199
# node created at [243, 619, 10]
# move 1
# move 2
# move 3
# node created with id 200
# node created at [257, 623, 1]
# move 4
# inside while
# closed list updated
# all list length is 200
# popped
# node created with id 201
# node created at [262, 632, 1]
# move 0
# move 1
# node created with id 202
# node created at [252, 632, 11]
# move 2
# Obstacle space
# move 3
# move 4
# inside while
# closed list updated
# all list length is 202
# popped
# Obstacle space
# move 0
# move 1
# node created with id 203
# node created at [257, 641, 11]
# move 2
# Obstacle space
# move 3
# move 4
# inside while
# closed list updated
# all list length is 203
# popped
# node created with id 204
# node created at [252, 650, 11]
# move 0
# node created with id 205
# node created at [248, 646, 10]
# move 1
# move 2
# move 3
# node created with id 206
# node created at [262, 650, 1]
# move 4
# inside while
# closed list updated
# all list length is 206
# popped
# node created with id 207
# node created at [267, 659, 1]
# move 0
# move 1
# node created with id 208
# node created at [257, 659, 11]
# move 2
# node created with id 209
# node created at [271, 655, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 209
# popped
# Obstacle space
# move 0
# node created with id 210
# node created at [276, 664, 1]
# move 1
# move 2
# move 3
# Obstacle space
# move 4
# inside while
# closed list updated
# all list length is 210
# popped
# node created with id 211
# node created at [281, 673, 1]
# move 0
# move 1
# node created with id 212
# node created at [271, 673, 11]
# move 2
# Obstacle space
# move 3
# move 4
# inside while
# closed list updated
# all list length is 212
# popped
# node created with id 213
# node created at [286, 682, 1]
# move 0
# move 1
# node created with id 214
# node created at [276, 682, 11]
# move 2
# node created with id 215
# node created at [290, 678, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 215
# popped
# Obstacle space
# move 0
# node created with id 216
# node created at [295, 687, 1]
# move 1
# move 2
# move 3
# Obstacle space
# move 4
# inside while
# closed list updated
# all list length is 216
# popped
# node created with id 217
# node created at [300, 696, 1]
# move 0
# move 1
# node created with id 218
# node created at [290, 696, 11]
# move 2
# node created with id 219
# node created at [304, 692, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 219
# popped
# node created with id 220
# node created at [313, 697, 2]
# move 0
# node created with id 221
# node created at [309, 701, 1]
# move 1
# move 2
# move 3
# Obstacle space
# move 4
# inside while
# closed list updated
# all list length is 221
# popped
# node created with id 222
# node created at [322, 702, 2]
# move 0
# node created with id 223
# node created at [318, 706, 1]
# move 1
# move 2
# move 3
# Obstacle space
# move 4
# inside while
# closed list updated
# all list length is 223
# popped
# node created with id 224
# node created at [331, 707, 2]
# move 0
# node created with id 225
# node created at [327, 711, 1]
# move 1
# move 2
# move 3
# Obstacle space
# move 4
# inside while
# closed list updated
# all list length is 225
# popped
# node created with id 226
# node created at [340, 712, 2]
# move 0
# node created with id 227
# node created at [336, 716, 1]
# move 1
# move 2
# move 3
# Obstacle space
# move 4
# inside while
# closed list updated
# all list length is 227
# popped
# node created with id 228
# node created at [349, 717, 2]
# move 0
# node created with id 229
# node created at [345, 721, 1]
# move 1
# move 2
# move 3
# node created with id 230
# node created at [349, 707, 4]
# move 4
# inside while
# closed list updated
# all list length is 230
# popped
# node created with id 231
# node created at [358, 722, 2]
# move 0
# node created with id 232
# node created at [354, 726, 1]
# move 1
# move 2
# move 3
# node created with id 233
# node created at [358, 712, 4]
# move 4
# inside while
# closed list updated
# all list length is 233
# popped
# node created with id 234
# node created at [367, 727, 2]
# move 0
# node created with id 235
# node created at [363, 731, 1]
# move 1
# move 2
# move 3
# node created with id 236
# node created at [367, 717, 4]
# move 4
# inside while
# closed list updated
# all list length is 236
# popped
# node created with id 237
# node created at [376, 732, 2]
# move 0
# node created with id 238
# node created at [372, 736, 1]
# move 1
# move 2
# move 3
# node created with id 239
# node created at [376, 722, 4]
# move 4
# inside while
# closed list updated
# all list length is 239
# popped
# node created with id 240
# node created at [385, 737, 2]
# move 0
# node created with id 241
# node created at [381, 741, 1]
# move 1
# move 2
# move 3
# node created with id 242
# node created at [385, 727, 4]
# move 4
# inside while
# closed list updated
# all list length is 242
# popped
# node created with id 243
# node created at [394, 742, 2]
# move 0
# node created with id 244
# node created at [390, 746, 1]
# move 1
# move 2
# move 3
# node created with id 245
# node created at [394, 732, 4]
# move 4
# inside while
# closed list updated
# all list length is 245
# popped
# node created with id 246
# node created at [403, 747, 2]
# move 0
# node created with id 247
# node created at [399, 751, 1]
# move 1
# move 2
# move 3
# node created with id 248
# node created at [403, 737, 4]
# move 4
# inside while
# closed list updated
# all list length is 248
# popped
# node created with id 249
# node created at [412, 752, 2]
# move 0
# node created with id 250
# node created at [408, 756, 1]
# move 1
# move 2
# move 3
# node created with id 251
# node created at [412, 742, 4]
# move 4
# inside while
# closed list updated
# all list length is 251
# popped
# node created with id 252
# node created at [421, 757, 2]
# move 0
# node created with id 253
# node created at [417, 761, 1]
# move 1
# move 2
# move 3
# node created with id 254
# node created at [421, 747, 4]
# move 4
# inside while
# closed list updated
# all list length is 254
# popped
# node created with id 255
# node created at [430, 762, 2]
# move 0
# node created with id 256
# node created at [426, 766, 1]
# move 1
# move 2
# move 3
# node created with id 257
# node created at [430, 752, 4]
# move 4
# inside while
# closed list updated
# all list length is 257
# popped
# node created with id 258
# node created at [439, 767, 2]
# move 0
# node created with id 259
# node created at [435, 771, 1]
# move 1
# move 2
# move 3
# node created with id 260
# node created at [439, 757, 4]
# move 4
# inside while
# closed list updated
# all list length is 260
# popped
# node created with id 261
# node created at [448, 772, 2]
# move 0
# node created with id 262
# node created at [444, 776, 1]
# move 1
# move 2
# move 3
# node created with id 263
# node created at [448, 762, 4]
# move 4
# inside while
# closed list updated
# all list length is 263
# popped
# node created with id 264
# node created at [457, 777, 2]
# move 0
# node created with id 265
# node created at [453, 781, 1]
# move 1
# move 2
# move 3
# node created with id 266
# node created at [457, 767, 4]
# move 4
# inside while
# closed list updated
# all list length is 266
# popped
# node created with id 267
# node created at [466, 782, 2]
# move 0
# node created with id 268
# node created at [462, 786, 1]
# move 1
# move 2
# move 3
# node created with id 269
# node created at [466, 772, 4]
# move 4
# inside while
# closed list updated
# all list length is 269
# popped
# node created with id 270
# node created at [475, 787, 2]
# move 0
# node created with id 271
# node created at [471, 791, 1]
# move 1
# move 2
# move 3
# node created with id 272
# node created at [475, 777, 4]
# move 4
# inside while
# closed list updated
# all list length is 272
# popped
# node created with id 273
# node created at [484, 792, 2]
# move 0
# node created with id 274
# node created at [480, 796, 1]
# move 1
# move 2
# move 3
# node created with id 275
# node created at [484, 782, 4]
# move 4
# inside while
# closed list updated
# all list length is 275
# popped
# node created with id 276
# node created at [493, 797, 2]
# move 0
# move 1
# move 2
# move 3
# node created with id 277
# node created at [493, 787, 4]
# move 4
# inside while
# closed list updated
# all list length is 277
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 277
# popped
# move 0
# move 1
# move 2
# node created with id 278
# node created at [498, 778, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 278
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 278
# popped
# node created with id 279
# node created at [493, 777, 4]
# move 0
# move 1
# node created with id 280
# node created at [493, 787, 2]
# move 2
# node created with id 281
# node created at [489, 773, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 281
# popped
# move 0
# node created with id 282
# node created at [498, 796, 1]
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 282
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 282
# popped
# move 0
# move 1
# move 2
# move 3
# node created with id 283
# node created at [493, 769, 7]
# move 4
# inside while
# closed list updated
# all list length is 283
# popped
# move 0
# move 1
# move 2
# node created with id 284
# node created at [498, 768, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 284
# popped
# move 0
# move 1
# move 2
# node created with id 285
# node created at [480, 796, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 285
# popped
# move 0
# move 1
# move 2
# move 3
# node created with id 286
# node created at [489, 791, 4]
# move 4
# inside while
# closed list updated
# all list length is 286
# popped
# node created with id 287
# node created at [498, 786, 4]
# move 0
# move 1
# node created with id 288
# node created at [498, 796, 2]
# move 2
# node created with id 289
# node created at [494, 782, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 289
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 289
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 289
# popped
# node created with id 290
# node created at [499, 773, 5]
# move 0
# move 1
# move 2
# move 3
# node created with id 291
# node created at [489, 773, 7]
# move 4
# inside while
# closed list updated
# all list length is 291
# popped
# node created with id 292
# node created at [494, 764, 5]
# move 0
# node created with id 293
# node created at [498, 768, 4]
# move 1
# move 2
# move 3
# node created with id 294
# node created at [484, 764, 7]
# move 4
# inside while
# closed list updated
# all list length is 294
# popped
# move 0
# move 1
# move 2
# move 3
# node created with id 295
# node created at [494, 764, 7]
# move 4
# inside while
# closed list updated
# all list length is 295
# popped
# Node exists, checking cost...
# move 0
# move 1
# Node exists, checking cost...
# move 2
# node created with id 296
# node created at [480, 768, 8]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 296
# popped
# node created with id 297
# node created at [484, 772, 4]
# move 0
# move 1
# node created with id 298
# node created at [484, 782, 2]
# move 2
# node created with id 299
# node created at [480, 768, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 299
# popped
# Node exists, checking cost...
# move 0
# node created with id 300
# node created at [489, 791, 1]
# move 1
# move 2
# move 3
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 300
# popped
# move 0
# move 1
# move 2
# Node exists, checking cost...
# move 3
# move 4
# inside while
# closed list updated
# all list length is 300
# popped
# node created with id 301
# node created at [493, 767, 4]
# move 0
# move 1
# node created with id 302
# node created at [493, 777, 2]
# move 2
# node created with id 303
# node created at [489, 763, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 303
# popped
# move 0
# node created with id 304
# node created at [498, 786, 1]
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 304
# popped
# move 0
# move 1
# node created with id 305
# node created at [493, 795, 11]
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 305
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 305
# popped
# move 0
# move 1
# move 2
# move 3
# node created with id 306
# node created at [493, 759, 7]
# move 4
# inside while
# closed list updated
# all list length is 306
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 306
# popped
# move 0
# move 1
# move 2
# node created with id 307
# node created at [498, 758, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 307
# popped
# node created with id 308
# node created at [488, 760, 7]
# move 0
# move 1
# node created with id 309
# node created at [498, 760, 5]
# move 2
# node created with id 310
# node created at [484, 764, 8]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 310
# popped
# node created with id 311
# node created at [485, 759, 5]
# move 0
# node created with id 312
# node created at [489, 763, 4]
# move 1
# move 2
# move 3
# node created with id 313
# node created at [475, 759, 7]
# move 4
# inside while
# closed list updated
# all list length is 313
# popped
# node created with id 314
# node created at [467, 795, 1]
# move 0
# move 1
# node created with id 315
# node created at [457, 795, 11]
# move 2
# node created with id 316
# node created at [471, 791, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 316
# popped
# Node exists, checking cost...
# move 0
# move 1
# move 2
# move 3
# node created with id 317
# node created at [480, 786, 4]
# move 4
# inside while
# closed list updated
# all list length is 317
# popped
# node created with id 318
# node created at [489, 781, 4]
# move 0
# move 1
# node created with id 319
# node created at [489, 791, 2]
# move 2
# node created with id 320
# node created at [485, 777, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 320
# popped
# Node exists, checking cost...
# move 0
# move 1
# move 2
# move 3
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 320
# popped
# node created with id 321
# node created at [498, 776, 4]
# move 0
# move 1
# node created with id 322
# node created at [498, 786, 2]
# move 2
# node created with id 323
# node created at [494, 772, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 323
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 323
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 323
# popped
# node created with id 324
# node created at [490, 768, 5]
# move 0
# node created with id 325
# node created at [494, 772, 4]
# move 1
# move 2
# move 3
# node created with id 326
# node created at [480, 768, 7]
# move 4
# inside while
# closed list updated
# all list length is 326
# popped
# node created with id 327
# node created at [499, 763, 5]
# move 0
# move 1
# move 2
# move 3
# node created with id 328
# node created at [489, 763, 7]
# move 4
# inside while
# closed list updated
# all list length is 328
# popped
# move 0
# move 1
# move 2
# Node exists, checking cost...
# move 3
# move 4
# inside while
# closed list updated
# all list length is 328
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 328
# popped
# node created with id 329
# node created at [495, 759, 5]
# move 0
# node created with id 330
# node created at [499, 763, 4]
# move 1
# move 2
# move 3
# node created with id 331
# node created at [485, 759, 7]
# move 4
# inside while
# closed list updated
# all list length is 331
# popped
# node created with id 332
# node created at [499, 755, 5]
# move 0
# move 1
# move 2
# move 3
# node created with id 333
# node created at [489, 755, 7]
# move 4
# inside while
# closed list updated
# all list length is 333
# popped
# Node exists, checking cost...
# move 0
# move 1
# Node exists, checking cost...
# move 2
# node created with id 334
# node created at [471, 763, 8]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 334
# popped
# node created with id 335
# node created at [494, 754, 5]
# move 0
# node created with id 336
# node created at [498, 758, 4]
# move 1
# move 2
# move 3
# node created with id 337
# node created at [484, 754, 7]
# move 4
# inside while
# closed list updated
# all list length is 337
# popped
# Node exists, checking cost...
# move 0
# move 1
# node created with id 338
# node created at [498, 768, 2]
# move 2
# Node exists, checking cost...
# move 3
# move 4
# inside while
# closed list updated
# all list length is 338
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 338
# popped
# move 0
# move 1
# move 2
# move 3
# node created with id 339
# node created at [494, 754, 7]
# move 4
# inside while
# closed list updated
# all list length is 339
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 339
# popped
# Node exists, checking cost...
# move 0
# move 1
# Node exists, checking cost...
# move 2
# node created with id 340
# node created at [485, 759, 8]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 340
# popped
# node created with id 341
# node created at [479, 755, 7]
# move 0
# move 1
# node created with id 342
# node created at [489, 755, 5]
# move 2
# node created with id 343
# node created at [475, 759, 8]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 343
# popped
# Node exists, checking cost...
# move 0
# Node exists, checking cost...
# move 1
# move 2
# move 3
# node created with id 344
# node created at [471, 773, 10]
# move 4
# inside while
# closed list updated
# all list length is 344
# popped
# Node exists, checking cost...
# move 0
# move 1
# Node exists, checking cost...
# move 2
# node created with id 345
# node created at [480, 758, 8]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 345
# popped
# node created with id 346
# node created at [475, 767, 4]
# move 0
# move 1
# node created with id 347
# node created at [475, 777, 2]
# move 2
# node created with id 348
# node created at [471, 763, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 348
# popped
# Node exists, checking cost...
# move 0
# node created with id 349
# node created at [480, 786, 1]
# move 1
# move 2
# move 3
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 349
# popped
# node created with id 350
# node created at [485, 795, 1]
# move 0
# move 1
# node created with id 351
# node created at [475, 795, 11]
# move 2
# Node exists, checking cost...
# move 3
# move 4
# inside while
# closed list updated
# all list length is 351
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 351
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 351
# popped
# node created with id 352
# node created at [484, 762, 4]
# move 0
# move 1
# node created with id 353
# node created at [484, 772, 2]
# move 2
# node created with id 354
# node created at [480, 758, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 354
# popped
# Node exists, checking cost...
# move 0
# node created with id 355
# node created at [489, 781, 1]
# move 1
# move 2
# move 3
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 355
# popped
# node created with id 356
# node created at [494, 790, 1]
# move 0
# move 1
# node created with id 357
# node created at [484, 790, 11]
# move 2
# Node exists, checking cost...
# move 3
# move 4
# inside while
# closed list updated
# all list length is 357
# popped
# node created with id 358
# node created at [499, 799, 1]
# move 0
# move 1
# node created with id 359
# node created at [489, 799, 11]
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 359
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 359
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 359
# popped
# node created with id 360
# node created at [479, 799, 11]
# move 0
# node created with id 361
# node created at [475, 795, 10]
# move 1
# move 2
# move 3
# node created with id 362
# node created at [489, 799, 1]
# move 4
# inside while
# closed list updated
# all list length is 362
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 362
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 362
# popped
# move 0
# move 1
# node created with id 363
# node created at [466, 790, 8]
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 363
# popped
# node created with id 364
# node created at [457, 785, 8]
# move 0
# node created with id 365
# node created at [461, 781, 7]
# move 1
# move 2
# move 3
# node created with id 366
# node created at [457, 795, 10]
# move 4
# inside while
# closed list updated
# all list length is 366
# popped
# node created with id 367
# node created at [493, 757, 4]
# move 0
# move 1
# node created with id 368
# node created at [493, 767, 2]
# move 2
# node created with id 369
# node created at [489, 753, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 369
# popped
# move 0
# node created with id 370
# node created at [498, 776, 1]
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 370
# popped
# move 0
# move 1
# node created with id 371
# node created at [493, 785, 11]
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 371
# popped
# node created with id 372
# node created at [488, 794, 11]
# move 0
# node created with id 373
# node created at [484, 790, 10]
# move 1
# move 2
# move 3
# node created with id 374
# node created at [498, 794, 1]
# move 4
# inside while
# closed list updated
# all list length is 374
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 374
# popped
# move 0
# node created with id 375
# node created at [479, 799, 10]
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 375
# popped
# Node exists, checking cost...
# move 0
# move 1
# node created with id 376
# node created at [475, 785, 8]
# move 2
# Node exists, checking cost...
# move 3
# move 4
# inside while
# closed list updated
# all list length is 376
# popped
# move 0
# move 1
# node created with id 377
# node created at [470, 794, 8]
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 377
# popped
# node created with id 378
# node created at [466, 780, 8]
# move 0
# node created with id 379
# node created at [470, 776, 7]
# move 1
# move 2
# move 3
# node created with id 380
# node created at [466, 790, 10]
# move 4
# inside while
# closed list updated
# all list length is 380
# popped
# node created with id 381
# node created at [461, 789, 8]
# move 0
# node created with id 382
# node created at [465, 785, 7]
# move 1
# move 2
# move 3
# node created with id 383
# node created at [461, 799, 10]
# move 4
# inside while
# closed list updated
# all list length is 383
# popped
# Node exists, checking cost...
# move 0
# move 1
# Node exists, checking cost...
# move 2
# node created with id 384
# node created at [461, 799, 11]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 384
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 384
# popped
# Node exists, checking cost...
# move 0
# Node exists, checking cost...
# move 1
# move 2
# move 3
# node created with id 385
# node created at [475, 769, 10]
# move 4
# inside while
# closed list updated
# all list length is 385
# popped
# node created with id 386
# node created at [465, 767, 7]
# move 0
# move 1
# node created with id 387
# node created at [475, 767, 5]
# move 2
# node created with id 388
# node created at [461, 771, 8]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 388
# popped
# node created with id 389
# node created at [462, 778, 10]
# move 0
# move 1
# node created with id 390
# node created at [462, 768, 8]
# move 2
# node created with id 391
# node created at [466, 782, 11]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 391
# popped
# node created with id 392
# node created at [461, 791, 11]
# move 0
# node created with id 393
# node created at [457, 787, 10]
# move 1
# move 2
# move 3
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 393
# popped
# move 0
# move 1
# move 2
# move 3
# node created with id 394
# node created at [493, 749, 7]
# move 4
# inside while
# closed list updated
# all list length is 394
# popped
# move 0
# move 1
# move 2
# move 3
# node created with id 395
# node created at [493, 751, 7]
# move 4
# inside while
# closed list updated
# all list length is 395
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 395
# popped
# node created with id 396
# node created at [466, 774, 10]
# move 0
# move 1
# node created with id 397
# node created at [466, 764, 8]
# move 2
# node created with id 398
# node created at [470, 778, 11]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 398
# popped
# node created with id 399
# node created at [465, 787, 11]
# move 0
# node created with id 400
# node created at [461, 783, 10]
# move 1
# move 2
# move 3
# node created with id 401
# node created at [475, 787, 1]
# move 4
# inside while
# closed list updated
# all list length is 401
# popped
# Node exists, checking cost...
# move 0
# move 1
# node created with id 402
# node created at [470, 796, 11]
# move 2
# Node exists, checking cost...
# move 3
# move 4
# inside while
# closed list updated
# all list length is 402
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 402
# popped
# node created with id 403
# node created at [460, 796, 11]
# move 0
# node created with id 404
# node created at [456, 792, 10]
# move 1
# move 2
# move 3
# node created with id 405
# node created at [470, 796, 1]
# move 4
# inside while
# closed list updated
# all list length is 405
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 405
# popped
# node created with id 406
# node created at [490, 750, 5]
# move 0
# node created with id 407
# node created at [494, 754, 4]
# move 1
# move 2
# move 3
# node created with id 408
# node created at [480, 750, 7]
# move 4
# inside while
# closed list updated
# all list length is 408
# popped
# move 0
# move 1
# move 2
# move 3
# node created with id 409
# node created at [490, 750, 7]
# move 4
# inside while
# closed list updated
# all list length is 409
# popped
# move 0
# move 1
# move 2
# node created with id 410
# node created at [498, 748, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 410
# popped
# node created with id 411
# node created at [488, 750, 7]
# move 0
# move 1
# node created with id 412
# node created at [498, 750, 5]
# move 2
# node created with id 413
# node created at [484, 754, 8]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 413
# popped
# node created with id 414
# node created at [460, 776, 7]
# move 0
# move 1
# node created with id 415
# node created at [470, 776, 5]
# move 2
# node created with id 416
# node created at [456, 780, 8]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 416
# popped
# node created with id 417
# node created at [457, 775, 8]
# move 0
# node created with id 418
# node created at [461, 771, 7]
# move 1
# move 2
# move 3
# node created with id 419
# node created at [457, 785, 10]
# move 4
# inside while
# closed list updated
# all list length is 419
# popped
# node created with id 420
# node created at [476, 754, 5]
# move 0
# node created with id 421
# node created at [480, 758, 4]
# move 1
# move 2
# move 3
# node created with id 422
# node created at [466, 754, 7]
# move 4
# inside while
# closed list updated
# all list length is 422
# popped
# node created with id 423
# node created at [483, 751, 7]
# move 0
# move 1
# node created with id 424
# node created at [493, 751, 5]
# move 2
# node created with id 425
# node created at [479, 755, 8]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 425
# popped
# Node exists, checking cost...
# move 0
# node created with id 426
# node created at [479, 771, 4]
# move 1
# move 2
# move 3
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 426
# popped
# node created with id 427
# node created at [488, 766, 4]
# move 0
# move 1
# node created with id 428
# node created at [488, 776, 2]
# move 2
# node created with id 429
# node created at [484, 762, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 429
# popped
# node created with id 430
# node created at [497, 781, 2]
# move 0
# node created with id 431
# node created at [493, 785, 1]
# move 1
# move 2
# move 3
# node created with id 432
# node created at [497, 771, 4]
# move 4
# inside while
# closed list updated
# all list length is 432
# popped
# Node exists, checking cost...
# move 0
# move 1
# Node exists, checking cost...
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 432
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 432
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 432
# popped
# node created with id 433
# node created at [497, 761, 4]
# move 0
# move 1
# node created with id 434
# node created at [497, 771, 2]
# move 2
# node created with id 435
# node created at [493, 757, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 435
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 435
# popped
# node created with id 436
# node created at [485, 749, 5]
# move 0
# node created with id 437
# node created at [489, 753, 4]
# move 1
# move 2
# move 3
# node created with id 438
# node created at [475, 749, 7]
# move 4
# inside while
# closed list updated
# all list length is 438
# popped
# Node exists, checking cost...
# move 0
# move 1
# node created with id 439
# node created at [489, 763, 2]
# move 2
# Node exists, checking cost...
# move 3
# move 4
# inside while
# closed list updated
# all list length is 439
# popped
# Node exists, checking cost...
# move 0
# node created with id 440
# node created at [494, 772, 1]
# move 1
# move 2
# move 3
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 440
# popped
# node created with id 441
# node created at [499, 781, 1]
# move 0
# move 1
# node created with id 442
# ...
# move 2
# move 3
# node created with id 575
# node created at [458, 772, 10]
# move 4
# inside while
# closed list updated
# all list length is 575
# popped
# node created with id 576
# node created at [494, 744, 5]
# move 0
# node created with id 577
# node created at [498, 748, 4]
# move 1
# move 2
# move 3
# node created with id 578
# node created at [484, 744, 7]
# move 4
# inside while
# closed list updated
# all list length is 578
# popped
# Node exists, checking cost...
# move 0
# move 1
# node created with id 579
# node created at [498, 758, 2]
# move 2
# Node exists, checking cost...
# move 3
# move 4
# inside while
# closed list updated
# all list length is 579
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 579
# popped
# node created with id 580
# node created at [452, 788, 10]
# move 0
# move 1
# node created with id 581
# node created at [452, 778, 8]
# move 2
# node created with id 582
# node created at [456, 792, 11]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 582
# popped
# Node exists, checking cost...
# move 0
# Node exists, checking cost...
# move 1
# move 2
# move 3
# node created with id 583
# node created at [466, 792, 1]
# move 4
# inside while
# closed list updated
# all list length is 583
# popped
# move 0
# move 1
# move 2
# node created with id 584
# node created at [475, 797, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 584
# popped
# move 0
# move 1
# move 2
# move 3
# node created with id 585
# node created at [484, 792, 4]
# move 4
# inside while
# closed list updated
# all list length is 585
# popped
# Node exists, checking cost...
# move 0
# move 1
# Node exists, checking cost...
# move 2
# node created with id 586
# node created at [489, 783, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 586
# popped
# node created with id 587
# node created at [494, 774, 5]
# move 0
# node created with id 588
# node created at [498, 778, 4]
# move 1
# move 2
# move 3
# node created with id 589
# node created at [484, 774, 7]
# move 4
# inside while
# closed list updated
# all list length is 589
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 589
# popped
# node created with id 590
# node created at [499, 765, 5]
# move 0
# move 1
# move 2
# move 3
# node created with id 591
# node created at [489, 765, 7]
# move 4
# inside while
# closed list updated
# all list length is 591
# popped
# node created with id 592
# node created at [479, 765, 7]
# move 0
# move 1
# node created with id 593
# node created at [489, 765, 5]
# move 2
# node created with id 594
# node created at [475, 769, 8]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 594
# popped
# move 0
# move 1
# move 2
# move 3
# node created with id 595
# node created at [494, 756, 7]
# move 4
# inside while
# closed list updated
# all list length is 595
# popped
# node created with id 596
# node created at [484, 746, 7]
# move 0
# move 1
# node created with id 597
# node created at [494, 746, 5]
# move 2
# node created with id 598
# node created at [480, 750, 8]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 598
# popped
# Node exists, checking cost...
# move 0
# node created with id 599
# node created at [498, 750, 4]
# move 1
# move 2
# move 3
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 599
# popped
# node created with id 600
# node created at [453, 783, 10]
# move 0
# move 1
# node created with id 601
# node created at [453, 773, 8]
# move 2
# node created with id 602
# node created at [457, 787, 11]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 602
# popped
# node created with id 603
# node created at [462, 758, 8]
# move 0
# Node exists, checking cost...
# move 1
# move 2
# move 3
# node created with id 604
# node created at [462, 768, 10]
# move 4
# inside while
# closed list updated
# all list length is 604
# popped
# node created with id 605
# node created at [484, 756, 7]
# move 0
# move 1
# node created with id 606
# node created at [494, 756, 5]
# move 2
# node created with id 607
# node created at [480, 760, 8]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 607
# popped
# Node exists, checking cost...
# move 0
# node created with id 608
# node created at [498, 760, 4]
# move 1
# move 2
# move 3
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 608
# popped
# node created with id 609
# node created at [461, 763, 7]
# move 0
# move 1
# Node exists, checking cost...
# move 2
# node created with id 610
# node created at [457, 767, 8]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 610
# popped
# Node exists, checking cost...
# move 0
# node created with id 611
# node created at [490, 758, 4]
# move 1
# move 2
# move 3
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 611
# popped
# node created with id 612
# node created at [499, 753, 4]
# move 0
# move 1
# node created with id 613
# node created at [499, 763, 2]
# move 2
# Node exists, checking cost...
# move 3
# move 4
# inside while
# closed list updated
# all list length is 613
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 613
# popped
# Node exists, checking cost...
# move 0
# Node exists, checking cost...
# move 1
# move 2
# move 3
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 613
# popped
# Node exists, checking cost...
# move 0
# Node exists, checking cost...
# move 1
# move 2
# move 3
# node created with id 614
# node created at [471, 763, 10]
# move 4
# inside while
# closed list updated
# all list length is 614
# popped
# node created with id 615
# node created at [448, 780, 8]
# move 0
# node created with id 616
# node created at [452, 776, 7]
# move 1
# move 2
# move 3
# node created with id 617
# node created at [448, 790, 10]
# move 4
# inside while
# closed list updated
# all list length is 617
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 617
# popped
# move 0
# move 1
# move 2
# move 3
# node created with id 618
# node created at [494, 744, 7]
# move 4
# inside while
# closed list updated
# all list length is 618
# popped
# node created with id 619
# node created at [476, 752, 8]
# move 0
# node created with id 620
# node created at [480, 748, 7]
# move 1
# move 2
# move 3
# node created with id 621
# node created at [476, 762, 10]
# move 4
# inside while
# closed list updated
# all list length is 621
# popped
# move 0
# move 1
# move 2
# move 3
# node created with id 622
# node created at [491, 745, 7]
# move 4
# inside while
# closed list updated
# all list length is 622
# popped
# node created with id 623
# node created at [479, 745, 7]
# move 0
# move 1
# node created with id 624
# node created at [489, 745, 5]
# move 2
# node created with id 625
# node created at [475, 749, 8]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 625
# popped
# Node exists, checking cost...
# move 0
# move 1
# Node exists, checking cost...
# move 2
# node created with id 626
# node created at [485, 749, 8]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 626
# popped
# node created with id 627
# node created at [453, 771, 8]
# move 0
# node created with id 628
# node created at [457, 767, 7]
# move 1
# move 2
# move 3
# node created with id 629
# node created at [453, 781, 10]
# move 4
# inside while
# closed list updated
# all list length is 629
# popped
# Node exists, checking cost...
# move 0
# move 1
# Node exists, checking cost...
# move 2
# node created with id 630
# node created at [471, 771, 11]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 630
# popped
# node created with id 631
# node created at [466, 780, 11]
# move 0
# node created with id 632
# node created at [462, 776, 10]
# move 1
# move 2
# move 3
# node created with id 633
# node created at [476, 780, 1]
# move 4
# inside while
# closed list updated
# all list length is 633
# popped
# node created with id 634
# node created at [481, 789, 1]
# move 0
# move 1
# node created with id 635
# node created at [471, 789, 11]
# move 2
# node created with id 636
# node created at [485, 785, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 636
# popped
# Node exists, checking cost...
# move 0
# node created with id 637
# node created at [490, 794, 1]
# move 1
# move 2
# move 3
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 637
# popped
# move 0
# move 1
# move 2
# node created with id 638
# node created at [499, 799, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 638
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 638
# popped
# node created with id 639
# node created at [486, 798, 1]
# move 0
# move 1
# node created with id 640
# node created at [476, 798, 11]
# move 2
# node created with id 641
# node created at [490, 794, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 641
# popped
# Node exists, checking cost...
# move 0
# move 1
# move 2
# move 3
# node created with id 642
# node created at [499, 789, 4]
# move 4
# inside while
# closed list updated
# all list length is 642
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 642
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 642
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 642
# popped
# node created with id 643
# node created at [466, 798, 11]
# move 0
# node created with id 644
# node created at [462, 794, 10]
# move 1
# move 2
# move 3
# node created with id 645
# node created at [476, 798, 1]
# move 4
# inside while
# closed list updated
# all list length is 645
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 645
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 645
# popped
# node created with id 646
# node created at [461, 789, 11]
# move 0
# Node exists, checking cost...
# move 1
# move 2
# move 3
# node created with id 647
# node created at [471, 789, 1]
# move 4
# inside while
# closed list updated
# all list length is 647
# popped
# Node exists, checking cost...
# move 0
# move 1
# Node exists, checking cost...
# move 2
# node created with id 648
# node created at [480, 794, 2]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 648
# popped
# node created with id 649
# node created at [489, 799, 2]
# move 0
# move 1
# move 2
# move 3
# node created with id 650
# node created at [489, 789, 4]
# move 4
# inside while
# closed list updated
# all list length is 650
# popped
# move 0
# move 1
# move 2
# move 3
# node created with id 651
# node created at [498, 794, 4]
# move 4
# inside while
# closed list updated
# all list length is 651
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 651
# popped
# node created with id 652
# node created at [498, 784, 4]
# move 0
# move 1
# node created with id 653
# node created at [498, 794, 2]
# move 2
# node created with id 654
# node created at [494, 780, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 654
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 654
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 654
# popped
# Node exists, checking cost...
# move 0
# move 1
# move 2
# move 3
# node created with id 655
# node created at [489, 771, 7]
# move 4
# inside while
# closed list updated
# all list length is 655
# popped
# node created with id 656
# node created at [484, 762, 7]
# move 0
# move 1
# Node exists, checking cost...
# move 2
# node created with id 657
# node created at [480, 766, 8]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 657
# popped
# node created with id 658
# node created at [453, 799, 10]
# move 0
# move 1
# node created with id 659
# node created at [453, 789, 8]
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 659
# popped
# node created with id 660
# node created at [456, 798, 11]
# move 0
# Node exists, checking cost...
# move 1
# move 2
# move 3
# node created with id 661
# node created at [466, 798, 1]
# move 4
# inside while
# closed list updated
# all list length is 661
# popped
# move 0
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 661
# popped
# Node exists, checking cost...
# move 0
# Node exists, checking cost...
# move 1
# move 2
# move 3
# node created with id 662
# node created at [466, 764, 10]
# move 4
# inside while
# closed list updated
# all list length is 662
# popped
# node created with id 663
# node created at [466, 762, 4]
# move 0
# move 1
# node created with id 664
# node created at [466, 772, 2]
# move 2
# node created with id 665
# node created at [462, 758, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 665
# popped
# Node exists, checking cost...
# move 0
# node created with id 666
# node created at [471, 781, 1]
# move 1
# move 2
# move 3
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 666
# popped
# Node exists, checking cost...
# updated cost of node 535 is 135.41
# move 0
# move 1
# Node exists, checking cost...
# updated cost of node 534 is 144.98
# move 2
# Node exists, checking cost...
# move 3
# move 4
# inside while
# closed list updated
# all list length is 666
# popped
# node created with id 667
# node created at [475, 757, 4]
# move 0
# move 1
# node created with id 668
# node created at [475, 767, 2]
# move 2
# node created with id 669
# node created at [471, 753, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 669
# popped
# Node exists, checking cost...
# move 0
# node created with id 670
# node created at [480, 776, 1]
# move 1
# move 2
# move 3
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 670
# popped
# node created with id 671
# node created at [485, 785, 1]
# move 0
# move 1
# node created with id 672
# node created at [475, 785, 11]
# move 2
# Node exists, checking cost...
# move 3
# move 4
# inside while
# closed list updated
# all list length is 672
# popped
# Node exists, checking cost...
# updated cost of node 637 is 122.94
# move 0
# move 1
# node created with id 673
# node created at [480, 794, 11]
# move 2
# Node exists, checking cost...
# move 3
# move 4
# inside while
# closed list updated
# all list length is 673
# popped
# move 0
# node created with id 674
# node created at [471, 799, 10]
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 674
# popped
# node created with id 675
# node created at [470, 794, 11]
# move 0
# Node exists, checking cost...
# updated cost of node 380 is 142.98
# move 1
# move 2
# move 3
# node created with id 676
# node created at [480, 794, 1]
# move 4
# inside while
# closed list updated
# all list length is 676
# popped
# move 0
# move 1
# move 2
# Node exists, checking cost...
# updated cost of node 649 is 124.06
# move 3
# move 4
# inside while
# closed list updated
# all list length is 676
# popped
# move 0
# move 1
# node created with id 677
# node created at [462, 794, 8]
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 677
# popped
# move 0
# Node exists, checking cost...
# updated cost of node 383 is 148.01
# move 1
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 677
# popped
# Node exists, checking cost...
# updated cost of node 659 is 160.89
# move 0
# node created with id 678
# node created at [457, 785, 7]
# move 1
# move 2
# move 3
# Node exists, checking cost...
# updated cost of node 658 is 160.01
# move 4
# inside while
# closed list updated
# all list length is 678
# popped
# node created with id 679
# node created at [484, 752, 4]
# move 0
# move 1
# node created with id 680
# node created at [484, 762, 2]
# move 2
# node created with id 681
# node created at [480, 748, 5]
# move 3
# move 4
# inside while
# closed list updated
# all list length is 681
# popped
# Node exists, checking cost...
# move 0
# node created with id 682
# node created at [489, 771, 1]
# move 1
# move 2
# move 3
# Node exists, checking cost...
# move 4
# inside while
# closed list updated
# all list length is 682
# popped
# node created with id 683
# node created at [494, 780, 1]
# move 0
# move 1
# node created with id 684
# node created at [484, 780, 11]
# move 2
# Node exists, checking cost...
# move 3
# move 4
# inside while
# closed list updated
# all list length is 684
# popped
# node created with id 685
# node created at [499, 789, 1]
# move 0
# move 1
# node created with id 686
# node created at [489, 789, 11]
# move 2
# move 3
# move 4
# inside while
# closed list updated
# all list length is 686
# popped
# move 0
# move 1
# node created with id 687
# node created at [494, 798, 11]
# move 2
# move 3
# move 4
# inside while
# closed list updated
# this will be done at [494, 798, 11]
# the goal coast is 112.0
# all list length is 687
# done

# %%
# Put animation here

#creating an empty canvas
canvas = np.zeros((int(250/Rat),int(400/Rat),3),np.uint8)

#list of all obstacles to put in canvas
for c in allp_map: #change the name of the variable l
    x = c[1]
    y = c[0]
    canvas[(x,y)]=[0,255,255] #assigning a yellow coloured pixel
canvas = np.flipud(canvas)
canvas_for_backtrack = canvas.copy()
canvas_for_visited = canvas.copy()
canvas_for_visited = cv2.resize(canvas_for_visited,(1200,750))
# #showing the obstacle map
# cv2.imshow('canvas',canvas)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

pygame.init()

display_width = int(400/Rat)
display_height = int(250/Rat)
display_h = 250
n = 2
m = n
s = n/Rat
# gameDisplay = pygame.display.set_mode((display_width,display_height),0, 32, 0, 10)
gameDisplay = pygame.display.set_mode((n*display_width,n*display_height))
# gameDisplay = pygame.display.set_mode((1920,1080),flags, vsync =1)
# gameDisplay = pygame.display.set_mode((0,0),pygame.FULLSCREEN)
pygame.display.set_caption('Visited Nodes- Animation')
black = (0,0,0)
white = (255,255,255)
Y = (255, 0,0)
B = (0,255,0)
surf = pygame.surfarray.make_surface(canvas_for_visited)

clock = pygame.time.Clock()
done = True
while done:
    for event in pygame.event.get():  
        if event.type == pygame.QUIT:  
            done = False  
    
    gameDisplay.fill(black)
    pygame.draw.circle(gameDisplay, B, (n*x_centre, n*(display_height-1-y_centre)), n*radius)
    pygame.draw.polygon(gameDisplay, B, [(s*114,s*(display_h-1-209)),(s*35,s*(display_h-1-184)), (s*104,s*(display_h-1-99)), (s*79,s*(display_h-1-179))])
    pygame.draw.polygon(gameDisplay, B, [(s*199,s*(display_h-1-59.6)),(s*234,s*(display_h-1-78.8)), (s*234,s*(display_h-1-119)), (s*200,s*(display_h-1-139)),(s*164,s*(display_h-1-119)),(s*164,s*(display_h-1-78.8))])
    for i in range(len(All_list)):
            p_id = All_list[i].parent_id
            if(i>0):
                x_start = All_list[p_id -1].node_loc[1]
                y1_start = All_list[p_id -1].node_loc[0]
                y_start = abs(display_height-1-y1_start)
                # print(x_start, y_start)
            else:
                x_start = All_list[p_id].node_loc[1]
                y1_start = All_list[p_id].node_loc[0]
                y_start = abs(display_height-1-y1_start)
            
            x = All_list[i].node_loc[1]
            y1 = All_list[i].node_loc[0]
            y = abs(display_height-1-y1)
            pygame.draw.line(gameDisplay, white, (n*x_start,n*y_start),(m*x,m*y), 1)
            pygame.display.flip()
            # pygame.time.wait(4)

    ind = int(map_obs4[All_list[goal_id].node_loc[0], All_list[goal_id].node_loc[1],All_list[goal_id].node_loc[2]])
    for i in range(len(x_a)-1):
            pygame.draw.line(gameDisplay, Y, (n*x_a[i],n*(display_height-y_a[i])),(n*x_a[i+1],n*(display_height-y_a[i+1])), 5)
            pygame.display.flip()
            # pygame.time.wait(4)
    done = False
    
    pygame.time.wait(4000)
    pygame.quit()

# %%
(200,59.6), (235,79.8), (235,120.2), (200,140.4), (165,120.2),(165,79.8)
# Out:
# ((199, 99), ())
